# %% [markdown]
# **Veri Setini Tanıma**
# Amaç:
#
#   - Veri setinin genel yapısını tanımak ve temel özelliklerini incelemek
#   - Veri analizi öncesi gerekli ilk kontrolleri uygulamak
#
# **Adımlar:**
#
# - Veri setini yükle
# - Veri setinin ilk ve son satırlarını incele
# - Veri setinin boyutunu ve sütunlarını kontrol etmek
# - Veri setinin genel bilgisini incele
# - Özet istatistikleri görüntüle
# - Veri tiplerini kontrol et
# - Sayısal ve kategorik sütunları ayırmak
# - Benzersiz (unique) değer sayılarını incelemek

# %%
import pandas as pd

# %%
df = pd.read_csv("e_ticaret_veri_seti.csv") #dataset yükle

# %%
df.head()  #eri önizleme
# Out:
#   siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391  2024-01-13 17:06:00   İstanbul            Marmara
# 1  SIP100837    MUS1347  2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu
# 2  SIP100050    MUS1066  2025-06-03 12:42:00    Kayseri         İç Anadolu
# 3  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya            Akdeniz
# 4  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
#
#      kategori              urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik          Nemlendirici     1       414.51           0.05
# 1        Spor           Dambıl Seti     2      1475.15           0.10
# 2       Kitap  İş Analitiği Rehberi     1       289.02           0.05
# 3       Kitap          Girişimcilik     5       194.78           0.00
# 4  Elektronik             Powerbank     3       841.80           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          29.9     Banka Kartı          VIP            4.0            1.0
# 2          29.9     Kredi Kartı       Mevcut            6.0            2.0
# 3          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 4          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar
# 0       Hayır            0.220        443.68
# 1       Hayır            0.361       2685.17
# 2       Hayır            0.348        304.47
# 3       Hayır            0.250       1023.80
# 4       Hayır            0.280       2439.03

# %%
df.tail()
# Out:
#      siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 1423  SIP101093    MUS1187  2024-06-08 20:42:00   İstanbul            Marmara
# 1424  SIP101193    MUS1297  2025-11-06 08:17:00  Gaziantep  Güneydoğu Anadolu
# 1425  SIP101210    MUS1122  2025-03-07 09:07:00        NaN            Marmara
# 1426  SIP101060    MUS1189  2025-04-19 21:52:00    Kocaeli            Marmara
# 1427  SIP100642    MUS1289  2024-09-22 16:36:00     Ankara         İç Anadolu
#
#         kategori         urun_adi  adet  birim_fiyat  indirim_orani  \
# 1423        Spor        Yoga Matı     1       772.23           0.00
# 1424        Spor            Suluk     2       187.03           0.00
# 1425  Elektronik           Webcam     4       894.47           0.10
# 1426       Kitap  Veri Bilimi 101     2       248.55           0.05
# 1427    Kozmetik      Güneş Kremi     1       424.84           0.20
#
#       kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 1423          29.9     Kredi Kartı       Mevcut            3.0            2.0
# 1424          59.9     Kredi Kartı         Yeni            2.0            4.0
# 1425          49.9     Kredi Kartı       Mevcut            3.0            5.0
# 1426          59.9     banka karti         Yeni            4.0            3.0
# 1427           0.0  Dijital Cüzdan         Yeni            2.0            4.0
#
#      iade_durumu  kar_marji_orani  toplam_tutar
# 1423       Hayır            0.275        802.13
# 1424        Evet            0.243        433.96
# 1425       Hayır            0.355       3269.99
# 1426       Hayır            0.373        532.14
# 1427       Hayır            0.317        339.87

# %%
satir_sayisi = df.shape[0]
satir_sayisi
# Out:
# 1428

# %%
sutun_sayisi= df.shape[1]
sutun_sayisi
# Out:
# 18

# %%
#sutun isimleri

for i, sutun in enumerate(df.columns):
    print(f"{i+1}. {sutun}")
# Out:
# 1. siparis_id
# 2. musteri_id
# 3. siparis_tarihi
# 4. sehir
# 5. bolge
# 6. kategori
# 7. urun_adi
# 8. adet
# 9. birim_fiyat
# 10. indirim_orani
# 11. kargo_ucreti
# 12. odeme_turu
# 13. musteri_tipi
# 14. teslimat_gunu
# 15. musteri_puani
# 16. iade_durumu
# 17. kar_marji_orani
# 18. toplam_tutar

# %%
# Veri setinin genel bilgisini inceleme
df.info() #sutun isimleri,missing values,data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1428 entries, 0 to 1427
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   siparis_id       1428 non-null   object
#  1   musteri_id       1428 non-null   object
#  2   siparis_tarihi   1428 non-null   object
#  3   sehir            1403 non-null   object
#  4   bolge            1428 non-null   object
#  5   kategori         1428 non-null   object
#  6   urun_adi         1428 non-null   object
#  7   adet             1428 non-null   int64
#  8   birim_fiyat      1428 non-null   float64
#  9   indirim_orani    1412 non-null   float64
#  10  kargo_ucreti     1428 non-null   float64
#  11  odeme_turu       1393 non-null   object
#  12  musteri_tipi     1386 non-null   object
#  13  teslimat_gunu    1400 non-null   float64
#  14  musteri_puani    1372 non-null   float64
#  15  iade_durumu      1428 non-null   object
#  16  kar_marji_orani  1428 non-null   float64
#  17  toplam_tutar     1428 non-null   float64
# dtypes: float64(7), int64(1), object(10)
# memory usage: 200.9+ KB

# %%
#sayısal sutunlar icin özet istatistikler
df.describe()
# Out:
#               adet   birim_fiyat  indirim_orani  kargo_ucreti  teslimat_gunu  \
# count  1428.000000   1428.000000    1412.000000   1428.000000    1400.000000
# mean      2.136555    658.477654       0.052054     39.725140       3.370714
# std       2.015770   1042.414639       0.060115     14.185017       1.825990
# min       1.000000     93.110000       0.000000      0.000000       1.000000
# 25%       1.000000    199.185000       0.000000     29.900000       2.000000
# 50%       2.000000    287.120000       0.050000     39.900000       3.000000
# 75%       3.000000    819.177500       0.100000     49.900000       4.000000
# max      38.000000  18145.230000       0.200000     59.900000      31.000000
#
#        musteri_puani  kar_marji_orani  toplam_tutar
# count    1372.000000      1428.000000   1428.000000
# mean        4.002187         0.302799   1370.590336
# std         1.096707         0.069795   2961.689500
# min         0.000000         0.180000     89.680000
# 25%         3.000000         0.244750    323.855000
# 50%         4.000000         0.305000    669.135000
# 75%         5.000000         0.362000   1390.950000
# max         7.000000         0.420000  63870.200000

# %%
# veri tipleirni kontrol etme
df.dtypes
# Out:
# siparis_id          object
# musteri_id          object
# siparis_tarihi      object
# sehir               object
# bolge               object
# kategori            object
# urun_adi            object
# adet                 int64
# birim_fiyat        float64
# indirim_orani      float64
# kargo_ucreti       float64
# odeme_turu          object
# musteri_tipi        object
# teslimat_gunu      float64
# musteri_puani      float64
# iade_durumu         object
# kar_marji_orani    float64
# toplam_tutar       float64
# dtype: object

# %%
#  Sayısal ve kategorik sütunların ayrılması
# sayısal: float64, int64

sayisal_sutunlar = df.select_dtypes(include=['float64', 'int64']).columns
sayisal_sutunlar
# Out:
# Index(['adet', 'birim_fiyat', 'indirim_orani', 'kargo_ucreti', 'teslimat_gunu',
#        'musteri_puani', 'kar_marji_orani', 'toplam_tutar'],
#       dtype='object')

# %%
# Benzersiz (unique) değer sayılarını incelemek
for sutun in df.columns:
  print(f"{sutun}: {df[sutun].nunique()} adet")
# Out:
# siparis_id: 1400 adet
# musteri_id: 422 adet
# siparis_tarihi: 1398 adet
# sehir: 19 adet
# bolge: 6 adet
# kategori: 15 adet
# urun_adi: 30 adet
# adet: 10 adet
# birim_fiyat: 1381 adet
# indirim_orani: 5 adet
# kargo_ucreti: 5 adet
# odeme_turu: 12 adet
# musteri_tipi: 7 adet
# teslimat_gunu: 11 adet
# musteri_puani: 8 adet
# iade_durumu: 2 adet
# kar_marji_orani: 241 adet
# toplam_tutar: 1397 adet

# %% [markdown]
# # Kayıp Veri (Missing Value)
# **Amaç:**
#
#
#  - Eksik veri tespiti ve farklı eksik veri çözüm yöntemlerini uygulamak
#  - Eğitimde kullanılacak güncel veri setini kaydetme
#
# **Adımlar:**
#
# 1. Veri setini yükleme
# 2. Eksik verileri tespit etme
# 3. Eksik veri oranlarını hesaplama
# 4. Eksik veri içeren satırları incele
# 5. Eksik verileri silmek
# 6. Sayısal eksik verileri ortalama ile doldur
# 7. Sayısal eksik verileri medyan ile doldur
# 8. Sayısal eksik verileri mod ile doldur
# 9. Kategorik eksik verileri mod ile doldur
# 10. Kategorik eksik verileri sabit bir değer ile doldurmak
# 11. Eğitimde kullanılacak olan güncel veri setini oluştur
# 12. Düzenlenmiş veri setini kaydet

# %%
#eksik verileir tespit etme
df.isnull().sum()
# Out:
# siparis_id          0
# musteri_id          0
# siparis_tarihi      0
# sehir              25
# bolge               0
# kategori            0
# urun_adi            0
# adet                0
# birim_fiyat         0
# indirim_orani      16
# kargo_ucreti        0
# odeme_turu         35
# musteri_tipi       42
# teslimat_gunu      28
# musteri_puani      56
# iade_durumu         0
# kar_marji_orani     0
# toplam_tutar        0
# dtype: int64

# %%
print('Eksik veri içeren sütunlar ve miktarları:\n')

df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Eksik veri içeren sütunlar ve miktarları:
# sehir            25
# indirim_orani    16
# odeme_turu       35
# musteri_tipi     42
# teslimat_gunu    28
# musteri_puani    56
# dtype: int64

# %%
# eksik veri oranlarını hesapla
eksik_veri_sayisi = df.isnull().sum()
eksik_veri_orani = 100 * eksik_veri_sayisi / len(df)
eksik_veri_orani[df.isnull().sum() > 0]
# Out:
# sehir            1.750700
# indirim_orani    1.120448
# odeme_turu       2.450980
# musteri_tipi     2.941176
# teslimat_gunu    1.960784
# musteri_puani    3.921569
# dtype: float64

# %%
# eksik veri içeren satırları incele

eksik_veri_olanlar = df[df.isnull().any(axis=1)]
eksik_veri_olanlar.head(10)
# Out:
#    siparis_id musteri_id       siparis_tarihi     sehir       bolge  \
# 19  SIP100677    MUS1148  2024-07-11 16:24:00     Adana     Akdeniz
# 33  SIP101126    MUS1406  2024-09-11 20:05:00    Mersin     Akdeniz
# 50  SIP101040    MUS1386  2025-04-01 09:30:00   Trabzon   Karadeniz
# 60  SIP100890    MUS1271  2024-11-07 19:47:00     İzmir         Ege
# 61  SIP101317    MUS1060  2024-09-05 20:49:00       NaN     Akdeniz
# 70  SIP100715    MUS1033  2024-11-10 21:50:00  İstanbul     Marmara
# 82  SIP100807    MUS1431  2025-01-07 14:12:00    Ankara  İç Anadolu
# 84  SIP100679    MUS1310  2024-05-20 18:51:00     İzmir         Ege
# 86  SIP101071    MUS1131  2024-09-18 12:24:00       NaN  İç Anadolu
# 92  SIP101366    MUS1347  2025-03-04 14:00:00     Bursa     Marmara
#
#        kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 19         Spor         Dambıl Seti     4      1517.65            0.0
# 33   Elektronik  Bluetooth Hoparlör     1      1159.89            0.1
# 50         Spor         Dambıl Seti     1      1554.15            0.0
# 60        Kitap        Girişimcilik     4       216.38            NaN
# 61  Ev ve Yaşam      Saklama Kutusu     1       233.63            0.1
# 70  Ev ve Yaşam              Termos     1       552.05            0.0
# 82     Kozmetik         Güneş Kremi     1       451.28            0.0
# 84  Ev ve Yaşam              Termos     2       477.62            0.0
# 86   Elektronik           Powerbank     1       816.74            0.0
# 92  Ev ve Yaşam           Organizer     1       272.40            0.0
#
#     kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 19          29.9    Kapıda Ödeme       Mevcut            3.0            NaN
# 33          39.9     Kredi Kartı          NaN            2.0            4.0
# 50          49.9     Banka Kartı          NaN            4.0            5.0
# 60          49.9     Kredi Kartı         Yeni            1.0            3.0
# 61          29.9  Dijital Cüzdan         Yeni            5.0            2.0
# 70          39.9             NaN       Mevcut            2.0            3.0
# 82          49.9     Kredi Kartı          NaN            4.0            5.0
# 84          49.9     Kredi Kartı       Mevcut            NaN            4.0
# 86          39.9     Banka Kartı         Yeni            3.0            5.0
# 92          29.9     Kredi Kartı       Mevcut            1.0            NaN
#
#    iade_durumu  kar_marji_orani  toplam_tutar
# 19       Hayır            0.311       6100.50
# 33       Hayır            0.204       1083.80
# 50       Hayır            0.217       1604.05
# 60       Hayır            0.199        915.42
# 61       Hayır            0.385        240.17
# 70       Hayır            0.185        591.95
# 82       Hayır            0.315        501.18
# 84       Hayır            0.323       1005.14
# 86       Hayır            0.301        856.64
# 92       Hayır            0.212        302.30

# %%
# Eksik verileri silme
df_silinen = df.dropna() # dropna ile eksik değer içeren satırları veri setinden çıkarttık

# %%
df_silinen.isnull().sum()
# Out:
# siparis_id         0
# musteri_id         0
# siparis_tarihi     0
# sehir              0
# bolge              0
# kategori           0
# urun_adi           0
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# odeme_turu         0
# musteri_tipi       0
# teslimat_gunu      0
# musteri_puani      0
# iade_durumu        0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
df_silinen.shape
# Out:
# (1239, 18)

# %%
#Sayısal eksik verilerin ortalama ile doldurulması
df_ortalama = df.copy()
sayisal_sutunlar = df_ortalama.select_dtypes(include = ["int64", "float64"]).columns
sayisal_sutunlar
# Out:
# Index(['adet', 'birim_fiyat', 'indirim_orani', 'kargo_ucreti', 'teslimat_gunu',
#        'musteri_puani', 'kar_marji_orani', 'toplam_tutar'],
#       dtype='object')

# %%
for sutun in sayisal_sutunlar:
  df_ortalama[sutun]=df_ortalama[sutun].fillna(df_ortalama[sutun].mean())

# %%
df_ortalama[sayisal_sutunlar].isnull().sum()
# Out:
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# teslimat_gunu      0
# musteri_puani      0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
# sayısal eksik verileri medyan ile doldurma
df_medyan = df.copy()
sayisal_sutunlar = df_medyan.select_dtypes(include = ["int64", "float64"]).columns
sayisal_sutunlar
# Out:
# Index(['adet', 'birim_fiyat', 'indirim_orani', 'kargo_ucreti', 'teslimat_gunu',
#        'musteri_puani', 'kar_marji_orani', 'toplam_tutar'],
#       dtype='object')

# %%
for sutun in sayisal_sutunlar:
  df_medyan[sutun]=df_medyan[sutun].fillna(df_medyan[sutun].median())
df_medyan[sayisal_sutunlar].isnull().sum()
# Out:
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# teslimat_gunu      0
# musteri_puani      0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
#Sayısal eksik verileri mod ile doldurma
df_mod_sayisal = df.copy()
for sutun in sayisal_sutunlar:
  mod_degeri = df_mod_sayisal[sutun].mode()[0]
  df_mod_sayisal[sutun] = df_mod_sayisal[sutun].fillna(mod_degeri)
df_mod_sayisal[sayisal_sutunlar].isnull().sum()
# Out:
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# teslimat_gunu      0
# musteri_puani      0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
# kategorik eksik verileri sabit bir değer ile doldurma
df_kategorikler = df.copy()
kategorik_sutunlar = df_kategorikler.select_dtypes(include=["object"]).columns
kategorik_sutunlar
# Out:
# Index(['siparis_id', 'musteri_id', 'siparis_tarihi', 'sehir', 'bolge',
#        'kategori', 'urun_adi', 'odeme_turu', 'musteri_tipi', 'iade_durumu'],
#       dtype='object')

# %%
for sutun in kategorik_sutunlar:
  df_kategorikler[sutun] = df_kategorikler[sutun].fillna("Belirtilmemiş")


df_kategorikler[kategorik_sutunlar].isnull().sum()
# Out:
# siparis_id        0
# musteri_id        0
# siparis_tarihi    0
# sehir             0
# bolge             0
# kategori          0
# urun_adi          0
# odeme_turu        0
# musteri_tipi      0
# iade_durumu       0
# dtype: int64

# %%
# eğitim için  güncel veri seti olsuturma
# - sayısal eksik verileri medyan ile doldur
# - kategorik eksik verileri mod ile doldur

# %%
df_guncel = df.copy()

# %%
for sutun in sayisal_sutunlar:
  df_guncel[sutun] = df_guncel[sutun].fillna(df_guncel[sutun].median())

# %%
for sutun in kategorik_sutunlar:
  mod_degeri = df_guncel[sutun].mode()[0]
  df_guncel[sutun] = df_guncel[sutun].fillna(mod_degeri)

# %%
df_guncel.isnull().sum()
# Out:
# siparis_id         0
# musteri_id         0
# siparis_tarihi     0
# sehir              0
# bolge              0
# kategori           0
# urun_adi           0
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# odeme_turu         0
# musteri_tipi       0
# teslimat_gunu      0
# musteri_puani      0
# iade_durumu        0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
# veri setini kaydetme
kayıt_ad= "eksik_veri_temizlenmis_veri_seti.csv"
df_guncel.to_csv(kayıt_ad, index=False)

# %% [markdown]
# # Veri Tipleri ve Dönüşümler
#
# **Amaç:**
# 1. Veri setindeki sütunlaırn veri tiplerini incelemek ve gerekli dönüşümleri uygulamak
#
# 2. Eğitimde kullanılacak güncel veri setini oluşturarak kaydetmek
#
# **Adımlar:**
# 1. Veri setini yüklemek
# 2. Veri tiplerini incelemek
# 3. Sayısal, kategorik ve tarih sütunlaırnı belirlemek
# 4. Sipariş tarihi sütununu datetime tipine dönüştürmek(string *> datetime)
# 5. Tarih sütunundan yeni özelliker üretmek(Feature extraction)
# 6. Kategorik sütunları category tipine dönüştürmek (string -> category)
# 7. Dönüşüm sonrası veri tipi kontrol etmek
# 8. Güncellenmiş veri setini kaydetmek

# %%
import pandas as pd

# %%
#load dataset
df = pd.read_csv("eksik_veri_temizlenmis_veri_seti.csv")
df.head()
# Out:
#   siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391  2024-01-13 17:06:00   İstanbul            Marmara
# 1  SIP100837    MUS1347  2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu
# 2  SIP100050    MUS1066  2025-06-03 12:42:00    Kayseri         İç Anadolu
# 3  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya            Akdeniz
# 4  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
#
#      kategori              urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik          Nemlendirici     1       414.51           0.05
# 1        Spor           Dambıl Seti     2      1475.15           0.10
# 2       Kitap  İş Analitiği Rehberi     1       289.02           0.05
# 3       Kitap          Girişimcilik     5       194.78           0.00
# 4  Elektronik             Powerbank     3       841.80           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          29.9     Banka Kartı          VIP            4.0            1.0
# 2          29.9     Kredi Kartı       Mevcut            6.0            2.0
# 3          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 4          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar
# 0       Hayır            0.220        443.68
# 1       Hayır            0.361       2685.17
# 2       Hayır            0.348        304.47
# 3       Hayır            0.250       1023.80
# 4       Hayır            0.280       2439.03

# %%
df.dtypes
# Out:
# siparis_id          object
# musteri_id          object
# siparis_tarihi      object
# sehir               object
# bolge               object
# kategori            object
# urun_adi            object
# adet                 int64
# birim_fiyat        float64
# indirim_orani      float64
# kargo_ucreti       float64
# odeme_turu          object
# musteri_tipi        object
# teslimat_gunu      float64
# musteri_puani      float64
# iade_durumu         object
# kar_marji_orani    float64
# toplam_tutar       float64
# dtype: object

# %%
# sayısal sutunlar
sayisal_sutunlar = df.select_dtypes(include = ["int64", "float64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar']

# %%
kategorik_sutunlar = df.select_dtypes(include = ["object"]).columns.tolist()
kategorik_sutunlar
# Out:
# ['siparis_id',
#  'musteri_id',
#  'siparis_tarihi',
#  'sehir',
#  'bolge',
#  'kategori',
#  'urun_adi',
#  'odeme_turu',
#  'musteri_tipi',
#  'iade_durumu']

# %%
df["siparis_tarihi"].dtype
# Out:
# dtype('O')

# %%
df['siparis_tarihi'] = pd.to_datetime(df['siparis_tarihi'])
df['siparis_tarihi'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.dtypes
# Out:
# siparis_id                 object
# musteri_id                 object
# siparis_tarihi     datetime64[ns]
# sehir                      object
# bolge                      object
# kategori                   object
# urun_adi                   object
# adet                        int64
# birim_fiyat               float64
# indirim_orani             float64
# kargo_ucreti              float64
# odeme_turu                 object
# musteri_tipi               object
# teslimat_gunu             float64
# musteri_puani             float64
# iade_durumu                object
# kar_marji_orani           float64
# toplam_tutar              float64
# dtype: object

# %%
# tarih sutunundan yeni özellikler üretelim
df["siparis_yili"] = df["siparis_tarihi"].dt.year
df["siparis_ayi"] = df["siparis_tarihi"].dt.month
df["siparis_gunu"] = df["siparis_tarihi"].dt.day
df["haftanın_gunu"] = df["siparis_tarihi"].dt.day_name()
df.head()
# Out:
#   siparis_id musteri_id      siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391 2024-01-13 17:06:00   İstanbul            Marmara
# 1  SIP100837    MUS1347 2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu
# 2  SIP100050    MUS1066 2025-06-03 12:42:00    Kayseri         İç Anadolu
# 3  SIP100263    MUS1008 2024-08-10 15:13:00    Antalya            Akdeniz
# 4  SIP100707    MUS1291 2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
#
#      kategori              urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik          Nemlendirici     1       414.51           0.05
# 1        Spor           Dambıl Seti     2      1475.15           0.10
# 2       Kitap  İş Analitiği Rehberi     1       289.02           0.05
# 3       Kitap          Girişimcilik     5       194.78           0.00
# 4  Elektronik             Powerbank     3       841.80           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          29.9     Banka Kartı          VIP            4.0            1.0
# 2          29.9     Kredi Kartı       Mevcut            6.0            2.0
# 3          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 4          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 0       Hayır            0.220        443.68          2024            1
# 1       Hayır            0.361       2685.17          2025            3
# 2       Hayır            0.348        304.47          2025            6
# 3       Hayır            0.250       1023.80          2024            8
# 4       Hayır            0.280       2439.03          2024            8
#
#    siparis_gunu haftanın_gunu
# 0            13      Saturday
# 1            17        Monday
# 2             3       Tuesday
# 3            10      Saturday
# 4            19        Monday

# %%
# aktegorik sutunları category tipine donusturme

kategorik_donusum_sutunlari = [
    "sehir",
    "kategori",
    "urun_adi",
    "odeme_turu",
    "musteri_tipi",
    "haftanın_gunu"
]

# %%
for sutun in kategorik_donusum_sutunlari:
  df[sutun] = df[sutun].astype("category")

# %%
df.dtypes
# Out:
# siparis_id                 object
# musteri_id                 object
# siparis_tarihi     datetime64[ns]
# sehir                    category
# bolge                      object
# kategori                 category
# urun_adi                 category
# adet                        int64
# birim_fiyat               float64
# indirim_orani             float64
# kargo_ucreti              float64
# odeme_turu               category
# musteri_tipi             category
# teslimat_gunu             float64
# musteri_puani             float64
# iade_durumu                object
# kar_marji_orani           float64
# toplam_tutar              float64
# siparis_yili                int32
# siparis_ayi                 int32
# siparis_gunu                int32
# haftanın_gunu            category
# dtype: object

# %%
#guncel dataseti kaydedelim

df.to_csv("e_ticaret_veri_seti_veri_tipleri_duzenlendi.csv")

# %% [markdown]
# # Tekrarlayan ve Tutarsız Kayıtlar
#  **Amaç:**
#  1. veri setindeki tekrarlayan ve tutarsız kayıtları tespit edip temizlemek
#  2. Eğitimde kullanılacak güncel veri setini kaydet
#
#  **Adımlar:**
#  1. Veri setini yüklemek
#  2. Tekrarlayan kayıtları tespit etmek
#  3. Tekrarlayan kayıtları incelemek
#  4. Tekrarayan kayıtları temilemek
#  5. Tutarsız kategorik değerleri incelemek
#  6. Sehir stunundaki tutarsız değerleri düzeltmek
#  7. Kategori sütunundaki tutarsız değerleridüzeltmek
#  8. Ödeme türü sutunundaki tutarsız değerleri düzeltmek
#  9. Müşteri tipi sütunundaki tuatrsız değerleri düzeltmek
#  10. Mantıksal oalrak hatalı kayıtları incele
#  11. Mantıksal oalrak hatalı kayıtları temizle
#
#   12. Guncel veri setini kaydet

# %%
# veri setini yukle
df = pd.read_csv("e_ticaret_veri_seti_veri_tipleri_duzenlendi.csv")
df.head()
# Out:
#    Unnamed: 0 siparis_id musteri_id       siparis_tarihi      sehir  \
# 0           0  SIP101125    MUS1391  2024-01-13 17:06:00   İstanbul
# 1           1  SIP100837    MUS1347  2025-03-17 21:13:00  Gaziantep
# 2           2  SIP100050    MUS1066  2025-06-03 12:42:00    Kayseri
# 3           3  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya
# 4           4  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep
#
#                bolge    kategori              urun_adi  adet  birim_fiyat  \
# 0            Marmara    Kozmetik          Nemlendirici     1       414.51
# 1  Güneydoğu Anadolu        Spor           Dambıl Seti     2      1475.15
# 2         İç Anadolu       Kitap  İş Analitiği Rehberi     1       289.02
# 3            Akdeniz       Kitap          Girişimcilik     5       194.78
# 4  Güneydoğu Anadolu  Elektronik             Powerbank     3       841.80
#
#    indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  \
# 0           0.05          49.9     Kredi Kartı         Yeni            3.0
# 1           0.10          29.9     Banka Kartı          VIP            4.0
# 2           0.05          29.9     Kredi Kartı       Mevcut            6.0
# 3           0.00          49.9    Kapıda Ödeme         Yeni            3.0
# 4           0.05          39.9  Dijital Cüzdan       Mevcut            4.0
#
#    musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  \
# 0            5.0       Hayır            0.220        443.68          2024
# 1            1.0       Hayır            0.361       2685.17          2025
# 2            2.0       Hayır            0.348        304.47          2025
# 3            5.0       Hayır            0.250       1023.80          2024
# 4            5.0       Hayır            0.280       2439.03          2024
#
#    siparis_ayi  siparis_gunu haftanın_gunu
# 0            1            13      Saturday
# 1            3            17        Monday
# 2            6             3       Tuesday
# 3            8            10      Saturday
# 4            8            19        Monday

# %%
df.shape
# Out:
# (1428, 23)

# %%
# tekrarayan kayıtları bul
tekrarlayan_kayitlar = df[df.duplicated()]
len(tekrarlayan_kayitlar)
# Out:
# 0

# %%
tekrarlayan_kayitlar.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, siparis_id, musteri_id, siparis_tarihi, sehir, bolge, kategori, urun_adi, adet, birim_fiyat, indirim_orani, kargo_ucreti, odeme_turu, musteri_tipi, teslimat_gunu, musteri_puani, iade_durumu, kar_marji_orani, toplam_tutar, siparis_yili, siparis_ayi, siparis_gunu, haftanın_gunu]
# Index: []

# %%
#tekrarlayan kayıtları tmizle
df= df.drop_duplicates()
df.shape
# Out:
# (1428, 23)

# %%
# tutarsız değerlerin incelenmesi

df['sehir'].unique()
# Out:
# array(['İstanbul', 'Gaziantep', 'Kayseri', 'Antalya', 'Konya', 'Ankara',
#        'Bursa', 'Trabzon', 'Adana', 'Mersin', 'Kocaeli', 'İzmir',
#        'Eskişehir', 'Samsun', 'istanbul', 'ankara', 'Istanbul',
#        'gaziantep', 'Izmir'], dtype=object)

# %%
df['kategori'].unique()
# Out:
# array(['Kozmetik', 'Spor', 'Kitap', 'Elektronik', 'Ofis', 'ofis',
#        'Ev ve Yaşam', 'Elektronik ', 'spor', 'kozmetık', 'ev ve yaşam',
#        'kitap', 'Kozmetik ', 'elektronik', 'Ev&Yaşam'], dtype=object)

# %%
df["odeme_turu"].unique()
# Out:
# array(['Kredi Kartı', 'Banka Kartı', 'Kapıda Ödeme', 'Dijital Cüzdan',
#        'Havale/EFT', 'Kart', 'kredi kartı', 'dijital cüzdan', 'eft',
#        'banka karti', 'Kapida Odeme', 'Havale'], dtype=object)

# %%
df["musteri_tipi"].unique()
# Out:
# array(['Yeni', 'VIP', 'Mevcut', 'yeni', 'Vip', 'mevcut', 'vip'],
#       dtype=object)

# %%
# yardımcı fonksiyon ile metinleri normlize edelim, bğyk kucuk harf donusumleri, bolslukların kaldırılması, turkce karakter kaynaklı farkların düzeltilmesi

def metin_normalize_et(series):
  return(
      series.astype(str)
      .str.strip()
      .str.lower()
      .str.replace("ş", "s" , regex=False)
      .str.replace("ı", "i" , regex=False)
      .str.replace("ğ", "g" , regex=False)
      .str.replace("ü", "u" , regex=False)
      .str.replace("ç", "c" , regex=False)
      .str.replace("ş", "s" , regex=False)
      .str.replace("ö", "o" , regex=False)
  )

# %%
#sehir stunundaki tuatrsız degerleri temizleme
df["sehir"] = metin_normalize_et(df["sehir"])
df["sehir"].unique()
# Out:
# array(['i̇stanbul', 'gaziantep', 'kayseri', 'antalya', 'konya', 'ankara',
#        'bursa', 'trabzon', 'adana', 'mersin', 'kocaeli', 'i̇zmir',
#        'eskisehir', 'samsun', 'istanbul', 'izmir'], dtype=object)

# %%
sehir_duzeltme_haritasi = {
    "istanbul": "İstanbul",
    "ankara": "Ankara",
    "izmir": "İzmir",
    "antalya": "Antalya",
    "konya": "Konya",
    "bursa": "Bursa",
    "adana": "Adana",
    "gaziantep": "Gaziantep",
    "mersin": "Mersin",
    "kayseri": "Kayseri",
    "eskisehir": "Eskişehir",
    "samsun": "Samsun",
    "trabzon": "Trabzon",
    "kocaeli": "Kocaeli"
}

# %%
df["sehir"] = df["sehir"].replace(sehir_duzeltme_haritasi)
df["sehir"].unique()
# Out:
# array(['i̇stanbul', 'Gaziantep', 'Kayseri', 'Antalya', 'Konya', 'Ankara',
#        'Bursa', 'Trabzon', 'Adana', 'Mersin', 'Kocaeli', 'i̇zmir',
#        'Eskişehir', 'Samsun', 'İstanbul', 'İzmir'], dtype=object)

# %%
# kateori sutunundaki tutarsız değerleri duzeltme
df["kategori"] = metin_normalize_et(df["kategori"])
df["kategori"].unique()
# Out:
# array(['kozmetik', 'spor', 'kitap', 'elektronik', 'ofis', 'ev ve yasam',
#        'ev&yasam'], dtype=object)

# %%
kategori_duzeltme_haritasi = {
    "elektronik": "Elektronik",
    "kitap": "Kitap",
    "kozmetik": "Kozmetik",
    "kozmetık": "Kozmetik",
    "spor": "Spor",
    "ev yasam": "Ev Yaşam",
    "ev ve yasam": "Ev Yaşam",
    "ev&yasam": "Ev Yaşam",
    "ofis": "Ofis"
}
df["kategori"] = df["kategori"].replace(kategori_duzeltme_haritasi)
df["kategori"].unique()
# Out:
# array(['Kozmetik', 'Spor', 'Kitap', 'Elektronik', 'Ofis', 'Ev Yaşam'],
#       dtype=object)

# %%
#ödeme türü sütunundaki tutarsız değerleri düzeltelim
df["odeme_turu"] = metin_normalize_et(df["odeme_turu"])
df["odeme_turu"].unique()
# Out:
# array(['kredi karti', 'banka karti', 'kapida odeme', 'dijital cuzdan',
#        'havale/eft', 'kart', 'eft', 'havale'], dtype=object)

# %%
odeme_turu_duzeltme_haritasi = {
    "kredi karti": "Kredi Kartı",
    "kart": "Kredi Kartı",
    "banka karti": "Banka Kartı",
    "dijital cuzdan": "Dijital Cüzdan",
    "kapida odeme": "Kapıda Ödeme",
    "havale": "Havale/EFT",
    "eft": "Havale/EFT",
    "havale/eft": "Havale/EFT"
}
df["odeme_turu"] = df["odeme_turu"].replace(odeme_turu_duzeltme_haritasi)
df["odeme_turu"].unique()
# Out:
# array(['Kredi Kartı', 'Banka Kartı', 'Kapıda Ödeme', 'Dijital Cüzdan',
#        'Havale/EFT'], dtype=object)

# %%
#müşteri tipi sütunundaki tutarsız değerleri düzeltelim
df["musteri_tipi"] = metin_normalize_et(df["musteri_tipi"])
df["musteri_tipi"].unique()
# Out:
# array(['yeni', 'vip', 'mevcut'], dtype=object)

# %%
musteri_tipi_duzeltme_haritasi = {
    "mevcut": "Mevcut",
    "yeni": "Yeni",
    "vip": "VIP"
}
df["musteri_tipi"] = df["musteri_tipi"].replace(musteri_tipi_duzeltme_haritasi)
df["musteri_tipi"].unique()
# Out:
# array(['Yeni', 'VIP', 'Mevcut'], dtype=object)

# %%
df["musteri_tipi"].value_counts()
# Out:
# musteri_tipi
# Mevcut    732
# Yeni      529
# VIP       167
# Name: count, dtype: int64

# %%
# mantıksal oalrak hatalı kayıtları inceleme
hatali_kayitlar = df[
    (df["adet"] <=0) |
    (df["toplam_tutar"] <= 0) |
    (df["birim_fiyat"] <= 0) |
    (df["teslimat_gunu"] < 0) |
    (df["musteri_puani"] < 0) |
    (df["musteri_puani"] > 5)

]

len(hatali_kayitlar)
# Out:
# 2

# %%
pd.set_option("display.max_columns", None)
hatali_kayitlar
# Out:
#       Unnamed: 0 siparis_id musteri_id       siparis_tarihi      sehir  \
# 609          609  SIP100095    MUS1165  2025-10-12 21:31:00  i̇stanbul
# 1008        1008  SIP101290    MUS1225  2024-01-16 21:46:00    Kocaeli
#
#         bolge  kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 609   Marmara  Kozmetik             Şampuan     2       190.17           0.10
# 1008  Marmara  Kozmetik  Yüz Temizleme Jeli     2       303.82           0.05
#
#       kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 609            0.0  Dijital Cüzdan       Mevcut            3.0            6.0
# 1008          29.9     Kredi Kartı         Yeni            5.0            7.0
#
#      iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 609        Hayır            0.416        342.31          2025           10
# 1008        Evet            0.287        607.16          2024            1
#
#       siparis_gunu haftanın_gunu
# 609             12        Sunday
# 1008            16       Tuesday

# %%
#mantıksal hataları temizleyelim
df = df[
    (df["adet"] > 0) &
    (df["toplam_tutar"] > 0) &
    (df["birim_fiyat"] > 0) &
    (df["teslimat_gunu"] >= 0) &
    (df["musteri_puani"] >= 0) &
    (df["musteri_puani"] <= 5)
]
df.shape
# Out:
# (1426, 23)

# %%
#güncellenmiş verinini kaydedilmesi
df.to_csv("e_ticaret_veri_seti_tekrarlayan_kayitlar_duzenlendi.csv")

# %% [markdown]
# # Aykırı Değerler (Outliers)
#
#
# ---
#
#
# **Amaç:**
#
# 1. Veri setindeki aykırı değerlerin tespit edilmesi ve incelenmesi
# 2. Aykırı değerleri temizleyerek güncel veri setinin oluşturulması
#
# **Adımlar:**
#
# 1. Veri setini yükle
# 2. Sayısal sütunları belirle
# 3. Sayısal sütunların özet istatistiklerini hesapla
# 4. IQR ile aykırı değer sınırlarını hesapla
# 5. Aykırı değer içeren kayıtları tespit etmek
# 6. Aykırı değer sayılarını sütun bazında incelemek
# 7. Aykırı değer içeren kayıtları veri setinden temizlemek
# 8. Temizlenmiş veri setini kaydetmek

# %%
# load dataset
df = pd.read_csv("e_ticaret_veri_seti_tekrarlayan_kayitlar_duzenlendi.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id       siparis_tarihi  \
# 0             0           0  SIP101125    MUS1391  2024-01-13 17:06:00
# 1             1           1  SIP100837    MUS1347  2025-03-17 21:13:00
# 2             2           2  SIP100050    MUS1066  2025-06-03 12:42:00
# 3             3           3  SIP100263    MUS1008  2024-08-10 15:13:00
# 4             4           4  SIP100707    MUS1291  2024-08-19 08:24:00
#
#        sehir              bolge    kategori              urun_adi  adet  \
# 0  i̇stanbul            Marmara    Kozmetik          Nemlendirici     1
# 1  Gaziantep  Güneydoğu Anadolu        Spor           Dambıl Seti     2
# 2    Kayseri         İç Anadolu       Kitap  İş Analitiği Rehberi     1
# 3    Antalya            Akdeniz       Kitap          Girişimcilik     5
# 4  Gaziantep  Güneydoğu Anadolu  Elektronik             Powerbank     3
#
#    birim_fiyat  indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  \
# 0       414.51           0.05          49.9     Kredi Kartı         Yeni
# 1      1475.15           0.10          29.9     Banka Kartı          VIP
# 2       289.02           0.05          29.9     Kredi Kartı       Mevcut
# 3       194.78           0.00          49.9    Kapıda Ödeme         Yeni
# 4       841.80           0.05          39.9  Dijital Cüzdan       Mevcut
#
#    teslimat_gunu  musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  \
# 0            3.0            5.0       Hayır            0.220        443.68
# 1            4.0            1.0       Hayır            0.361       2685.17
# 2            6.0            2.0       Hayır            0.348        304.47
# 3            3.0            5.0       Hayır            0.250       1023.80
# 4            4.0            5.0       Hayır            0.280       2439.03
#
#    siparis_yili  siparis_ayi  siparis_gunu haftanın_gunu
# 0          2024            1            13      Saturday
# 1          2025            3            17        Monday
# 2          2025            6             3       Tuesday
# 3          2024            8            10      Saturday
# 4          2024            8            19        Monday

# %%
# sayisal sutunların belirlenmesi
sayisal_sutunlar = df.select_dtypes(include = ["int64", "float64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['Unnamed: 0.1',
#  'Unnamed: 0',
#  'adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar',
#  'siparis_yili',
#  'siparis_ayi',
#  'siparis_gunu']

# %%
# sayisal sutunların özel istatistikleri
df[sayisal_sutunlar].describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0         adet   birim_fiyat  indirim_orani  \
# count   1426.000000  1426.000000  1426.000000   1426.000000    1426.000000
# mean     713.366760   713.366760     2.136746    659.054769       0.051999
# std      412.578627   412.578627     2.017178   1043.029657       0.059806
# min        0.000000     0.000000     1.000000     93.110000       0.000000
# 25%      356.250000   356.250000     1.000000    199.365000       0.000000
# 50%      713.500000   713.500000     2.000000    287.120000       0.050000
# 75%     1070.750000  1070.750000     3.000000    820.452500       0.100000
# max     1427.000000  1427.000000    38.000000  18145.230000       0.200000
#
#        kargo_ucreti  teslimat_gunu  musteri_puani  kar_marji_orani  \
# count   1426.000000    1426.000000    1426.000000      1426.000000
# mean      39.759888       3.362553       3.998597         0.302731
# std       14.153470       1.809441       1.071479         0.069778
# min        0.000000       1.000000       0.000000         0.180000
# 25%       29.900000       2.000000       4.000000         0.244250
# 50%       39.900000       3.000000       4.000000         0.305000
# 75%       49.900000       4.000000       5.000000         0.362000
# max       59.900000      31.000000       5.000000         0.420000
#
#        toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu
# count   1426.000000   1426.000000  1426.000000   1426.000000
# mean    1371.846795   2024.534362     6.395512     15.640252
# std     2963.572697      0.498993     3.453646      8.707990
# min       89.680000   2024.000000     1.000000      1.000000
# 25%      323.405000   2024.000000     3.000000      8.000000
# 50%      670.965000   2025.000000     6.000000     16.000000
# 75%     1393.250000   2025.000000     9.000000     23.000000
# max    63870.200000   2025.000000    12.000000     31.000000

# %%
"""birim_fiyat
  IQR = Q3(75%) - Q1(25%)
      = 817 - 198 = 619
  Üst sınır = Q3 + k*IQR
  Alt sınır = Q1 - k*IQR
    k = 1 olsun
    Üst sınır = 817 + 619 = 1436
    Alt sınır = 198 - 619 = -421
  Outlier = üst sınır ve alt sınır dışında kalan örnekler
"""
# Out:
# 'birim_fiyat\n  IQR = Q3(75%) - Q1(25%)\n      = 817 - 198 = 619\n  Üst sınır = Q3 + k*IQR\n  Alt sınır = Q1 - k*IQR\n    k = 1 olsun\n    Üst sınır = 817 + 619 = 1436\n    Alt sınır = 198 - 619 = -421\n  Outlier = üst sınır ve alt sınır dışında kalan örnekler\n'

# %%
# IQR ile aykırı deger sınırlarını hesaplama
aykiri_sinirlar = {}

for sutun in sayisal_sutunlar:

  q1 = df[sutun].quantile(0.25)
  q3 = df[sutun].quantile(0.75)

  iqr = q3 - q1
  alt_sinir = q1 - 1.5 * iqr
  ust_sinir = q3 + 1.5 * iqr

  aykiri_sinirlar[sutun] = {
      "q1": q1,
      "q3": q3,
      "iqr": iqr,
      "alt_sinir": alt_sinir,
      "ust_sinir": ust_sinir
  }

# %%
aykiri_sinirlar
# Out:
# {'Unnamed: 0.1': {'q1': np.float64(356.25),
#   'q3': np.float64(1070.75),
#   'iqr': np.float64(714.5),
#   'alt_sinir': np.float64(-715.5),
#   'ust_sinir': np.float64(2142.5)},
#  'Unnamed: 0': {'q1': np.float64(356.25),
#   'q3': np.float64(1070.75),
#   'iqr': np.float64(714.5),
#   'alt_sinir': np.float64(-715.5),
#   'ust_sinir': np.float64(2142.5)},
#  'adet': {'q1': np.float64(1.0),
#   'q3': np.float64(3.0),
#   'iqr': np.float64(2.0),
#   'alt_sinir': np.float64(-2.0),
#   'ust_sinir': np.float64(6.0)},
#  'birim_fiyat': {'q1': np.float64(199.365),
#   'q3': np.float64(820.4525),
#   'iqr': np.float64(621.0875),
#   'alt_sinir': np.float64(-732.2662499999999),
#   'ust_sinir': np.float64(1752.0837499999998)},
#  'indirim_orani': {'q1': np.float64(0.0),
#   'q3': np.float64(0.1),
#   'iqr': np.float64(0.1),
#   'alt_sinir': np.float64(-0.15000000000000002),
#   'ust_sinir': np.float64(0.25)},
#  'kargo_ucreti': {'q1': np.float64(29.9),
#   'q3': np.float64(49.9),
#   'iqr': np.float64(20.0),
#   'alt_sinir': np.float64(-0.10000000000000142),
#   'ust_sinir': np.float64(79.9)},
#  'teslimat_gunu': {'q1': np.float64(2.0),
#   'q3': np.float64(4.0),
#   'iqr': np.float64(2.0),
#   'alt_sinir': np.float64(-1.0),
#   'ust_sinir': np.float64(7.0)},
#  'musteri_puani': {'q1': np.float64(4.0),
#   'q3': np.float64(5.0),
#   'iqr': np.float64(1.0),
#   'alt_sinir': np.float64(2.5),
#   'ust_sinir': np.float64(6.5)},
#  'kar_marji_orani': {'q1': np.float64(0.24425),
#   'q3': np.float64(0.362),
#   'iqr': np.float64(0.11775),
#   'alt_sinir': np.float64(0.06762500000000002),
#   'ust_sinir': np.float64(0.5386249999999999)},
#  'toplam_tutar': {'q1': np.float64(323.405),
#   'q3': np.float64(1393.25),
#   'iqr': np.float64(1069.845),
#   'alt_sinir': np.float64(-1281.3625),
#   'ust_sinir': np.float64(2998.0175)},
#  'siparis_yili': {'q1': np.float64(2024.0),
#   'q3': np.float64(2025.0),
#   'iqr': np.float64(1.0),
#   'alt_sinir': np.float64(2022.5),
#   'ust_sinir': np.float64(2026.5)},
#  'siparis_ayi': {'q1': np.float64(3.0),
#   'q3': np.float64(9.0),
#   'iqr': np.float64(6.0),
#   'alt_sinir': np.float64(-6.0),
#   'ust_sinir': np.float64(18.0)},
#  'siparis_gunu': {'q1': np.float64(8.0),
#   'q3': np.float64(23.0),
#   'iqr': np.float64(15.0),
#   'alt_sinir': np.float64(-14.5),
#   'ust_sinir': np.float64(45.5)}}

# %%
# aykırı değer içeren kaıtlaı tespit et
aykiri_maskesi = pd.Series(False, index = df.index)

for sutun in sayisal_sutunlar:
  alt_sinir = aykiri_sinirlar[sutun]["alt_sinir"]
  ust_sinir = aykiri_sinirlar[sutun]["ust_sinir"]

  sutun_maskesi = (df[sutun] < alt_sinir) | (df[sutun] > ust_sinir)
  aykiri_maskesi = aykiri_maskesi | sutun_maskesi

# %%
aykiri_kayitlar = df[aykiri_maskesi]
aykiri_kayitlar
# Out:
#       Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id       siparis_tarihi  \
# 1                1           1  SIP100837    MUS1347  2025-03-17 21:13:00
# 2                2           2  SIP100050    MUS1066  2025-06-03 12:42:00
# 6                6           6  SIP101351    MUS1011  2025-02-27 11:35:00
# 7                7           7  SIP101172    MUS1357  2024-07-22 13:26:00
# 8                8           8  SIP100779    MUS1354  2025-12-05 11:19:00
# ...            ...         ...        ...        ...                  ...
# 1414          1416        1416  SIP100177    MUS1075  2024-01-29 13:59:00
# 1416          1418        1418  SIP100056    MUS1238  2024-04-19 20:27:00
# 1417          1419        1419  SIP101279    MUS1149  2024-08-24 08:38:00
# 1421          1423        1423  SIP101093    MUS1187  2024-06-08 20:42:00
# 1423          1425        1425  SIP101210    MUS1122  2025-03-07 09:07:00
#
#           sehir              bolge    kategori              urun_adi  adet  \
# 1     Gaziantep  Güneydoğu Anadolu        Spor           Dambıl Seti     2
# 2       Kayseri         İç Anadolu       Kitap  İş Analitiği Rehberi     1
# 6     i̇stanbul            Marmara        Ofis             Mouse Pad     3
# 7        Ankara         İç Anadolu        Ofis        Mekanik Klavye     3
# 8     i̇stanbul            Marmara       Kitap        Python Notları     4
# ...         ...                ...         ...                   ...   ...
# 1414    Trabzon          Karadeniz        Ofis        Mekanik Klavye     3
# 1416     Ankara         İç Anadolu       Kitap       Veri Bilimi 101     2
# 1417     Ankara         İç Anadolu  Elektronik           Akıllı Saat     4
# 1421  i̇stanbul            Marmara        Spor             Yoga Matı     1
# 1423  i̇stanbul            Marmara  Elektronik                Webcam     4
#
#       birim_fiyat  indirim_orani  kargo_ucreti   odeme_turu musteri_tipi  \
# 1         1475.15           0.10          29.9  Banka Kartı          VIP
# 2          289.02           0.05          29.9  Kredi Kartı       Mevcut
# 6          169.47           0.05          29.9   Havale/EFT          VIP
# 7         2344.47           0.00          59.9  Kredi Kartı       Mevcut
# 8          219.14           0.00          29.9  Kredi Kartı         Yeni
# ...           ...            ...           ...          ...          ...
# 1414      2169.51           0.00          39.9  Kredi Kartı       Mevcut
# 1416       255.70           0.05          59.9  Kredi Kartı       Mevcut
# 1417      3074.80           0.15          39.9  Banka Kartı         Yeni
# 1421       772.23           0.00          29.9  Kredi Kartı       Mevcut
# 1423       894.47           0.10          49.9  Kredi Kartı       Mevcut
#
#       teslimat_gunu  musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  \
# 1               4.0            1.0       Hayır            0.361       2685.17
# 2               6.0            2.0       Hayır            0.348        304.47
# 6               3.0            2.0        Evet            0.382        512.89
# 7               3.0            4.0       Hayır            0.312       7093.31
# 8              18.0            5.0        Evet            0.408        906.46
# ...             ...            ...         ...              ...           ...
# 1414            1.0            4.0       Hayır            0.273       6548.43
# 1416            3.0            2.0       Hayır            0.247        545.73
# 1417            4.0            5.0       Hayır            0.414      10494.22
# 1421            3.0            2.0       Hayır            0.275        802.13
# 1423            3.0            5.0       Hayır            0.355       3269.99
#
#       siparis_yili  siparis_ayi  siparis_gunu haftanın_gunu
# 1             2025            3            17        Monday
# 2             2025            6             3       Tuesday
# 6             2025            2            27      Thursday
# 7             2024            7            22        Monday
# 8             2025           12             5        Friday
# ...            ...          ...           ...           ...
# 1414          2024            1            29        Monday
# 1416          2024            4            19        Friday
# 1417          2024            8            24      Saturday
# 1421          2024            6             8      Saturday
# 1423          2025            3             7        Friday
#
# [308 rows x 24 columns]

# %%
# aykırı değer sayılarını sutun bazında ıncele
for sutun in sayisal_sutunlar:

  alt_sinir = aykiri_sinirlar[sutun]["alt_sinir"]
  ust_sinir = aykiri_sinirlar[sutun]["ust_sinir"]

  aykiri_sayi = ((df[sutun] < alt_sinir) | (df[sutun] > ust_sinir)).sum()
  print(f"{sutun}: {aykiri_sayi}")
# Out:
# Unnamed: 0.1: 0
# Unnamed: 0: 0
# adet: 6
# birim_fiyat: 92
# indirim_orani: 0
# kargo_ucreti: 0
# teslimat_gunu: 6
# musteri_puani: 154
# kar_marji_orani: 0
# toplam_tutar: 135
# siparis_yili: 0
# siparis_ayi: 0
# siparis_gunu: 0

# %%
df_temiz = df[~aykiri_maskesi].copy()
df_temiz.shape
# Out:
# (1118, 24)

# %%
#temizlenmiş veri setini kaydet
df_temiz.to_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")

# %% [markdown]
# # Kategorik Veri Analizi
# **Amaç:**
#
#
# 1.  Veri setindeki kategorik sütunları incelemek ve dağılımlarını analiz etmek
#
# 2. Frekans, oran ve görselleştirme yöntemleri ile kategorik verileri yorumlama
#
#  **Adımlar:**
#
# 1. Veri setini yüklemek
# 2. Kategorik sütunları belirlemek
# 3. Kategorik sütunların genel bilgisini incelemek
# 4. Her kategorik sütun için frekans analizi yapmak
# 5. Her kategorik sütun için oran analizi yapmak
# 6. En sık görülen kategorileri incele
# 7. En az görülen kategorileri incele
# 8. Belirli sütunlar üzerinde detaylı kategorik analiz
# 9. Belirli sütunlar için count plot çizdirme

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
print("ok")
# Out:
# ok

# %%
#kategorik sutunları belirle
kategorik_sutunlar = df.select_dtypes(include = ["object", "category"]).columns.tolist()
kategorik_sutunlar
# Out:
# ['siparis_id',
#  'musteri_id',
#  'siparis_tarihi',
#  'sehir',
#  'bolge',
#  'kategori',
#  'urun_adi',
#  'odeme_turu',
#  'musteri_tipi',
#  'iade_durumu',
#  'haftanın_gunu']

# %%
#kategorik sutunların genel bilgisinin incelenmesi
for sutun in kategorik_sutunlar:
  print(f"sutun adı: {sutun}")
  print(f"veri tipi: {df[sutun].dtype}")
  print(f"benzersiz deger sayısı: {df[sutun].nunique()}")
  print()
# Out:
# sutun adı: siparis_id
# veri tipi: object
# benzersiz deger sayısı: 1096
#
# sutun adı: musteri_id
# veri tipi: object
# benzersiz deger sayısı: 411
#
# sutun adı: siparis_tarihi
# veri tipi: object
# benzersiz deger sayısı: 1095
#
# sutun adı: sehir
# veri tipi: object
# benzersiz deger sayısı: 15
#
# sutun adı: bolge
# veri tipi: object
# benzersiz deger sayısı: 6
#
# sutun adı: kategori
# veri tipi: object
# benzersiz deger sayısı: 6
#
# sutun adı: urun_adi
# veri tipi: object
# benzersiz deger sayısı: 28
#
# sutun adı: odeme_turu
# veri tipi: object
# benzersiz deger sayısı: 5
#
# sutun adı: musteri_tipi
# veri tipi: object
# benzersiz deger sayısı: 3
#
# sutun adı: iade_durumu
# veri tipi: object
# benzersiz deger sayısı: 2
#
# sutun adı: haftanın_gunu
# veri tipi: object
# benzersiz deger sayısı: 7

# %%
# her kategorik sutun icin frekans analizi yapalım
for sutun in kategorik_sutunlar:
  print(df[sutun].value_counts())
  print()
# Out:
# siparis_id
# SIP100725    2
# SIP100368    2
# SIP100479    2
# SIP100868    2
# SIP100030    2
#             ..
# SIP100970    1
# SIP100464    1
# SIP101252    1
# SIP100273    1
# SIP100159    1
# Name: count, Length: 1096, dtype: int64
#
# musteri_id
# MUS1433    9
# MUS1360    8
# MUS1289    7
# MUS1204    7
# MUS1328    7
#           ..
# MUS1443    1
# MUS1335    1
# MUS1375    1
# MUS1239    1
# MUS1088    1
# Name: count, Length: 411, dtype: int64
#
# siparis_tarihi
# 2025-05-25 21:46:00    2
# 2024-06-20 20:34:00    2
# 2024-04-19 11:24:00    2
# 2025-05-24 10:10:00    2
# 2024-11-19 14:22:00    2
#                       ..
# 2025-05-30 16:44:00    1
# 2025-03-13 15:26:00    1
# 2024-01-18 16:52:00    1
# 2025-08-31 15:11:00    1
# 2025-02-04 08:59:00    1
# Name: count, Length: 1095, dtype: int64
#
# sehir
# i̇stanbul    264
# Ankara       126
# i̇zmir       121
# Antalya       86
# Konya         78
# Bursa         69
# Adana         64
# Gaziantep     52
# Samsun        47
# Mersin        46
# Trabzon       45
# Eskişehir     45
# Kayseri       39
# Kocaeli       32
# İstanbul       4
# Name: count, dtype: int64
#
# bolge
# Marmara              357
# İç Anadolu           290
# Akdeniz              196
# Ege                  127
# Karadeniz             95
# Güneydoğu Anadolu     53
# Name: count, dtype: int64
#
# kategori
# Kitap         227
# Kozmetik      203
# Spor          192
# Ev Yaşam      186
# Ofis          165
# Elektronik    145
# Name: count, dtype: int64
#
# urun_adi
# Suluk                   52
# Powerbank               51
# Zaman Yönetimi          48
# Not Tutucu              48
# Veri Bilimi 101         48
# Python Notları          47
# Saklama Kutusu          45
# İş Analitiği Rehberi    43
# Yüz Temizleme Jeli      42
# Girişimcilik            41
# Şampuan                 41
# Nemlendirici            41
# Direnç Bandı            41
# Serum                   41
# Kalem Seti              40
# Defter Seti             40
# Termos                  38
# Güneş Kremi             38
# Spor Çantası            37
# Mouse Pad               37
# Yoga Matı               36
# Kahve Kupası            35
# Masa Lambası            35
# Webcam                  35
# Bluetooth Hoparlör      33
# Organizer               33
# Kablosuz Kulaklık       26
# Dambıl Seti             26
# Name: count, dtype: int64
#
# odeme_turu
# Kredi Kartı       595
# Banka Kartı       174
# Dijital Cüzdan    157
# Havale/EFT        112
# Kapıda Ödeme       80
# Name: count, dtype: int64
#
# musteri_tipi
# Mevcut    572
# Yeni      416
# VIP       130
# Name: count, dtype: int64
#
# iade_durumu
# Hayır    1029
# Evet       89
# Name: count, dtype: int64
#
# haftanın_gunu
# Saturday     173
# Tuesday      173
# Wednesday    165
# Thursday     159
# Sunday       155
# Monday       147
# Friday       146
# Name: count, dtype: int64

# %%
# her sutun icin oran analizi yapalım
for sutun in kategorik_sutunlar:
  print((df[sutun].value_counts(normalize=True) * 100).round(2))
  print()
# Out:
# siparis_id
# SIP100725    0.18
# SIP100368    0.18
# SIP100479    0.18
# SIP100868    0.18
# SIP100030    0.18
#              ...
# SIP100970    0.09
# SIP100464    0.09
# SIP101252    0.09
# SIP100273    0.09
# SIP100159    0.09
# Name: proportion, Length: 1096, dtype: float64
#
# musteri_id
# MUS1433    0.81
# MUS1360    0.72
# MUS1289    0.63
# MUS1204    0.63
# MUS1328    0.63
#            ...
# MUS1443    0.09
# MUS1335    0.09
# MUS1375    0.09
# MUS1239    0.09
# MUS1088    0.09
# Name: proportion, Length: 411, dtype: float64
#
# siparis_tarihi
# 2025-05-25 21:46:00    0.18
# 2024-06-20 20:34:00    0.18
# 2024-04-19 11:24:00    0.18
# 2025-05-24 10:10:00    0.18
# 2024-11-19 14:22:00    0.18
#                        ...
# 2025-05-30 16:44:00    0.09
# 2025-03-13 15:26:00    0.09
# 2024-01-18 16:52:00    0.09
# 2025-08-31 15:11:00    0.09
# 2025-02-04 08:59:00    0.09
# Name: proportion, Length: 1095, dtype: float64
#
# sehir
# i̇stanbul    23.61
# Ankara       11.27
# i̇zmir       10.82
# Antalya       7.69
# Konya         6.98
# Bursa         6.17
# Adana         5.72
# Gaziantep     4.65
# Samsun        4.20
# Mersin        4.11
# Trabzon       4.03
# Eskişehir     4.03
# Kayseri       3.49
# Kocaeli       2.86
# İstanbul      0.36
# Name: proportion, dtype: float64
#
# bolge
# Marmara              31.93
# İç Anadolu           25.94
# Akdeniz              17.53
# Ege                  11.36
# Karadeniz             8.50
# Güneydoğu Anadolu     4.74
# Name: proportion, dtype: float64
#
# kategori
# Kitap         20.30
# Kozmetik      18.16
# Spor          17.17
# Ev Yaşam      16.64
# Ofis          14.76
# Elektronik    12.97
# Name: proportion, dtype: float64
#
# urun_adi
# Suluk                   4.65
# Powerbank               4.56
# Zaman Yönetimi          4.29
# Not Tutucu              4.29
# Veri Bilimi 101         4.29
# Python Notları          4.20
# Saklama Kutusu          4.03
# İş Analitiği Rehberi    3.85
# Yüz Temizleme Jeli      3.76
# Girişimcilik            3.67
# Şampuan                 3.67
# Nemlendirici            3.67
# Direnç Bandı            3.67
# Serum                   3.67
# Kalem Seti              3.58
# Defter Seti             3.58
# Termos                  3.40
# Güneş Kremi             3.40
# Spor Çantası            3.31
# Mouse Pad               3.31
# Yoga Matı               3.22
# Kahve Kupası            3.13
# Masa Lambası            3.13
# Webcam                  3.13
# Bluetooth Hoparlör      2.95
# Organizer               2.95
# Kablosuz Kulaklık       2.33
# Dambıl Seti             2.33
# Name: proportion, dtype: float64
#
# odeme_turu
# Kredi Kartı       53.22
# Banka Kartı       15.56
# Dijital Cüzdan    14.04
# Havale/EFT        10.02
# Kapıda Ödeme       7.16
# Name: proportion, dtype: float64
#
# musteri_tipi
# Mevcut    51.16
# Yeni      37.21
# VIP       11.63
# Name: proportion, dtype: float64
#
# iade_durumu
# Hayır    92.04
# Evet      7.96
# Name: proportion, dtype: float64
#
# haftanın_gunu
# Saturday     15.47
# Tuesday      15.47
# Wednesday    14.76
# Thursday     14.22
# Sunday       13.86
# Monday       13.15
# Friday       13.06
# Name: proportion, dtype: float64

# %%
# ens sık gorulen kategorileri incele
for sutun in kategorik_sutunlar:
  print()
  print(df[sutun].value_counts().head(3))
# Out:
# siparis_id
# SIP100725    2
# SIP100368    2
# SIP100479    2
# Name: count, dtype: int64
#
# musteri_id
# MUS1433    9
# MUS1360    8
# MUS1289    7
# Name: count, dtype: int64
#
# siparis_tarihi
# 2025-05-25 21:46:00    2
# 2024-06-20 20:34:00    2
# 2024-04-19 11:24:00    2
# Name: count, dtype: int64
#
# sehir
# i̇stanbul    264
# Ankara       126
# i̇zmir       121
# Name: count, dtype: int64
#
# bolge
# Marmara       357
# İç Anadolu    290
# Akdeniz       196
# Name: count, dtype: int64
#
# kategori
# Kitap       227
# Kozmetik    203
# Spor        192
# Name: count, dtype: int64
#
# urun_adi
# Suluk             52
# Powerbank         51
# Zaman Yönetimi    48
# Name: count, dtype: int64
#
# odeme_turu
# Kredi Kartı       595
# Banka Kartı       174
# Dijital Cüzdan    157
# Name: count, dtype: int64
#
# musteri_tipi
# Mevcut    572
# Yeni      416
# VIP       130
# Name: count, dtype: int64
#
# iade_durumu
# Hayır    1029
# Evet       89
# Name: count, dtype: int64
#
# haftanın_gunu
# Saturday     173
# Tuesday      173
# Wednesday    165
# Name: count, dtype: int64

# %%
# en az görülen kategorileri inceleyelim
for sutun in kategorik_sutunlar:
  print()
  print(df[sutun].value_counts().tail(3))
# Out:
# siparis_id
# SIP101252    1
# SIP100273    1
# SIP100159    1
# Name: count, dtype: int64
#
# musteri_id
# MUS1375    1
# MUS1239    1
# MUS1088    1
# Name: count, dtype: int64
#
# siparis_tarihi
# 2024-01-18 16:52:00    1
# 2025-08-31 15:11:00    1
# 2025-02-04 08:59:00    1
# Name: count, dtype: int64
#
# sehir
# Kayseri     39
# Kocaeli     32
# İstanbul     4
# Name: count, dtype: int64
#
# bolge
# Ege                  127
# Karadeniz             95
# Güneydoğu Anadolu     53
# Name: count, dtype: int64
#
# kategori
# Ev Yaşam      186
# Ofis          165
# Elektronik    145
# Name: count, dtype: int64
#
# urun_adi
# Organizer            33
# Kablosuz Kulaklık    26
# Dambıl Seti          26
# Name: count, dtype: int64
#
# odeme_turu
# Dijital Cüzdan    157
# Havale/EFT        112
# Kapıda Ödeme       80
# Name: count, dtype: int64
#
# musteri_tipi
# Mevcut    572
# Yeni      416
# VIP       130
# Name: count, dtype: int64
#
# iade_durumu
# Hayır    1029
# Evet       89
# Name: count, dtype: int64
#
# haftanın_gunu
# Sunday    155
# Monday    147
# Friday    146
# Name: count, dtype: int64

# %%
#belirli sütunlar üzerinde detaylı kategorik analiz
detayli_analiz_sutunlari = ["sehir", "kategori","odeme_turu","musteri_tipi"]

for sutun in detayli_analiz_sutunlari:
  if sutun in df.columns:
    print("Frekanslar: ")
    print(df[sutun].value_counts())

    print("Oranlar: ")
    print((df[sutun].value_counts(normalize=True) * 100).round(2))
# Out:
# Frekanslar:
# sehir
# i̇stanbul    264
# Ankara       126
# i̇zmir       121
# Antalya       86
# Konya         78
# Bursa         69
# Adana         64
# Gaziantep     52
# Samsun        47
# Mersin        46
# Trabzon       45
# Eskişehir     45
# Kayseri       39
# Kocaeli       32
# İstanbul       4
# Name: count, dtype: int64
# Oranlar:
# sehir
# i̇stanbul    23.61
# Ankara       11.27
# i̇zmir       10.82
# Antalya       7.69
# Konya         6.98
# Bursa         6.17
# Adana         5.72
# Gaziantep     4.65
# Samsun        4.20
# Mersin        4.11
# Trabzon       4.03
# Eskişehir     4.03
# Kayseri       3.49
# Kocaeli       2.86
# İstanbul      0.36
# Name: proportion, dtype: float64
# Frekanslar:
# kategori
# Kitap         227
# Kozmetik      203
# Spor          192
# Ev Yaşam      186
# Ofis          165
# Elektronik    145
# Name: count, dtype: int64
# Oranlar:
# kategori
# Kitap         20.30
# Kozmetik      18.16
# Spor          17.17
# Ev Yaşam      16.64
# Ofis          14.76
# Elektronik    12.97
# Name: proportion, dtype: float64
# Frekanslar:
# odeme_turu
# Kredi Kartı       595
# Banka Kartı       174
# Dijital Cüzdan    157
# Havale/EFT        112
# Kapıda Ödeme       80
# Name: count, dtype: int64
# Oranlar:
# odeme_turu
# Kredi Kartı       53.22
# Banka Kartı       15.56
# Dijital Cüzdan    14.04
# Havale/EFT        10.02
# Kapıda Ödeme       7.16
# Name: proportion, dtype: float64
# Frekanslar:
# musteri_tipi
# Mevcut    572
# Yeni      416
# VIP       130
# Name: count, dtype: int64
# Oranlar:
# musteri_tipi
# Mevcut    51.16
# Yeni      37.21
# VIP       11.63
# Name: proportion, dtype: float64

# %%
# belirli sutunlar icin countplot çizdirme
for sutun in detayli_analiz_sutunlari:
  plt.figure(figsize=(6,3))
  sns.countplot(data=df, x = sutun, order = df[sutun].value_counts().index)
  plt.title(f"{sutun} için count plot")
  plt.xlabel(sutun)
  plt.ylabel("Frekans")
  plt.xticks(rotation=45)
  plt.show()

# %% [markdown]
# # Sayısal Veri Analizi
# **Amaç:**
#
# 1. Veri setindeki analiz için uygun sayısal sütunları incelemek
# 2. Temel istatistikler ve histogram ile dağılım yapısını değerlendirmek
#
# **Adımlar:**
#
# 1. Veri setini yüklemek
# 2. Sayısal sütunları belirlemek
# 3. Analiz için uygun sayısal sütunları seçmek
# 4. Seçilen sütunların genel bilgisini incelemek
# 5. Temel istatistikleri hesapla
# 6. Histogram çizdir

# %%
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id  \
# 0                0             0           0  SIP101125    MUS1391
# 1                3             3           3  SIP100263    MUS1008
# 2                4             4           4  SIP100707    MUS1291
# 3                5             5           5  SIP100687    MUS1147
# 4               10            10          10  SIP100254    MUS1447
# ...            ...           ...         ...        ...        ...
# 1113          1419          1421        1421  SIP100480    MUS1323
# 1114          1420          1422        1422  SIP101222    MUS1440
# 1115          1422          1424        1424  SIP101193    MUS1297
# 1116          1424          1426        1426  SIP101060    MUS1189
# 1117          1425          1427        1427  SIP100642    MUS1289
#
#            siparis_tarihi      sehir              bolge    kategori  \
# 0     2024-01-13 17:06:00  i̇stanbul            Marmara    Kozmetik
# 1     2024-08-10 15:13:00    Antalya            Akdeniz       Kitap
# 2     2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu  Elektronik
# 3     2025-08-09 08:42:00      Konya         İç Anadolu    Kozmetik
# 4     2024-07-30 09:06:00      Konya         İç Anadolu  Elektronik
# ...                   ...        ...                ...         ...
# 1113  2024-06-20 20:34:00     Ankara         İç Anadolu  Elektronik
# 1114  2025-05-14 09:21:00      Bursa            Marmara        Spor
# 1115  2025-11-06 08:17:00  Gaziantep  Güneydoğu Anadolu        Spor
# 1116  2025-04-19 21:52:00    Kocaeli            Marmara       Kitap
# 1117  2024-09-22 16:36:00     Ankara         İç Anadolu    Kozmetik
#
#                 urun_adi  adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# 0           Nemlendirici     1       414.51           0.05          49.9
# 1           Girişimcilik     5       194.78           0.00          49.9
# 2              Powerbank     3       841.80           0.05          39.9
# 3           Nemlendirici     2       417.02           0.00          59.9
# 4     Bluetooth Hoparlör     1      1327.75           0.05          29.9
# ...                  ...   ...          ...            ...           ...
# 1113   Kablosuz Kulaklık     1      1468.25           0.05          39.9
# 1114         Dambıl Seti     1      1488.18           0.00          29.9
# 1115               Suluk     2       187.03           0.00          59.9
# 1116     Veri Bilimi 101     2       248.55           0.05          59.9
# 1117         Güneş Kremi     1       424.84           0.20           0.0
#
#           odeme_turu musteri_tipi  teslimat_gunu  musteri_puani iade_durumu  \
# 0        Kredi Kartı         Yeni            3.0            5.0       Hayır
# 1       Kapıda Ödeme         Yeni            3.0            5.0       Hayır
# 2     Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
# 3     Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
# 4        Banka Kartı       Mevcut            4.0            5.0       Hayır
# ...              ...          ...            ...            ...         ...
# 1113     Banka Kartı       Mevcut            2.0            4.0       Hayır
# 1114     Kredi Kartı       Mevcut            3.0            4.0       Hayır
# 1115     Kredi Kartı         Yeni            2.0            4.0        Evet
# 1116     Banka Kartı         Yeni            4.0            3.0       Hayır
# 1117  Dijital Cüzdan         Yeni            2.0            4.0       Hayır
#
#       kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 0               0.220        443.68          2024            1            13
# 1               0.250       1023.80          2024            8            10
# 2               0.280       2439.03          2024            8            19
# 3               0.220        893.94          2025            8             9
# 4               0.283       1291.26          2024            7            30
# ...               ...           ...           ...          ...           ...
# 1113            0.275       1434.74          2024            6            20
# 1114            0.189       1518.08          2025            5            14
# 1115            0.243        433.96          2025           11             6
# 1116            0.373        532.14          2025            4            19
# 1117            0.317        339.87          2024            9            22
#
#      haftanın_gunu
# 0         Saturday
# 1         Saturday
# 2           Monday
# 3         Saturday
# 4          Tuesday
# ...            ...
# 1113      Thursday
# 1114     Wednesday
# 1115      Thursday
# 1116      Saturday
# 1117        Sunday
#
# [1118 rows x 25 columns]

# %%
sayisal_sutunlar = df.select_dtypes(include = ["int64", "float64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['Unnamed: 0.2',
#  'Unnamed: 0.1',
#  'Unnamed: 0',
#  'adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar',
#  'siparis_yili',
#  'siparis_ayi',
#  'siparis_gunu']

# %%
df = df.drop(columns = ['Unnamed: 0.2','Unnamed: 0.1','Unnamed: 0',])

# %%
df.head()
# Out:
#   siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391  2024-01-13 17:06:00  i̇stanbul            Marmara
# 1  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya            Akdeniz
# 2  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 3  SIP100687    MUS1147  2025-08-09 08:42:00      Konya         İç Anadolu
# 4  SIP100254    MUS1447  2024-07-30 09:06:00      Konya         İç Anadolu
#
#      kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik        Nemlendirici     1       414.51           0.05
# 1       Kitap        Girişimcilik     5       194.78           0.00
# 2  Elektronik           Powerbank     3       841.80           0.05
# 3    Kozmetik        Nemlendirici     2       417.02           0.00
# 4  Elektronik  Bluetooth Hoparlör     1      1327.75           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 2          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 3          59.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 4          29.9     Banka Kartı       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 0       Hayır            0.220        443.68          2024            1
# 1       Hayır            0.250       1023.80          2024            8
# 2       Hayır            0.280       2439.03          2024            8
# 3       Hayır            0.220        893.94          2025            8
# 4       Hayır            0.283       1291.26          2024            7
#
#    siparis_gunu haftanın_gunu
# 0            13      Saturday
# 1            10      Saturday
# 2            19        Monday
# 3             9      Saturday
# 4            30       Tuesday

# %%
sayisal_sutunlar
# Out:
# ['Unnamed: 0.2',
#  'Unnamed: 0.1',
#  'Unnamed: 0',
#  'adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar',
#  'siparis_yili',
#  'siparis_ayi',
#  'siparis_gunu']

# %%
# analiz icin uygun sayısal sutunlar
analiz_sutunlari = ["birim_fiyat", "toplam_tutar", "teslimat_gunu", "musteri_puani"]

# %%
for sutun in analiz_sutunlari:
  if sutun in df.columns:
    print(f"Sütun: {sutun}")
    print(f"Veri tipi: {df[sutun].dtype}")
    print(f"Benzersiz değer sayısı: {df[sutun].nunique()}")
    print()
# Out:
# Sütun: birim_fiyat
# Veri tipi: float64
# Benzersiz değer sayısı: 1081
#
# Sütun: toplam_tutar
# Veri tipi: float64
# Benzersiz değer sayısı: 1093
#
# Sütun: teslimat_gunu
# Veri tipi: float64
# Benzersiz değer sayısı: 7
#
# Sütun: musteri_puani
# Veri tipi: float64
# Benzersiz değer sayısı: 3

# %%
# temel istatistikleri hesapla
df[analiz_sutunlari].describe()
# Out:
#        birim_fiyat  toplam_tutar  teslimat_gunu  musteri_puani
# count  1118.000000   1118.000000    1118.000000    1118.000000
# mean    438.961494    781.018989       3.307692       4.282648
# std     366.164831    632.296649       1.444947       0.708488
# min      93.110000     89.680000       1.000000       3.000000
# 25%     193.040000    293.215000       2.000000       4.000000
# 50%     262.160000    565.505000       3.000000       4.000000
# 75%     590.465000   1022.210000       4.000000       5.000000
# max    1751.140000   2990.840000       7.000000       5.000000

# %%
# histogram cizdrme
for sutun in analiz_sutunlari:
  plt.figure(figsize=(6,3))
  plt.hist(df[sutun], bins=80)
  plt.title(f"{sutun} için histogram")
  plt.xlabel(sutun)
  plt.ylabel("Frekans")
  plt.show()

# %% [markdown]
# # Grup Bazlı Analiz
#
# **Amaç:**
#
# 1. Veri setini farklı kırılımlara ayırarak grup bazlı analizler yapalım
# 2. groupby yapısı ile özet istatistikler üretip sonuçları yorumlamak
#
# **Adımlar:**
#
# 1. Veri setini yüklemek
# 2. Grup bazlı analiz için kullanılacak sütunları belirle
# 3. Kategoriye göre temel analiz
# 4. Şehre göre temel analiz
# 5. Müşteri tipine göre temel analiz
# 6. Ödeme türüne göre temel analiz
# 7. Birden fazla sütun ile grup bazlı analiz

# %%
import pandas as pd
pd.set_option("display.max_columns", None)
print("ok")
# Out:
# ok

# %%
# veri setini yukle
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")

# %%
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id  \
# 0             0             0           0  SIP101125    MUS1391
# 1             3             3           3  SIP100263    MUS1008
# 2             4             4           4  SIP100707    MUS1291
# 3             5             5           5  SIP100687    MUS1147
# 4            10            10          10  SIP100254    MUS1447
#
#         siparis_tarihi      sehir              bolge    kategori  \
# 0  2024-01-13 17:06:00  i̇stanbul            Marmara    Kozmetik
# 1  2024-08-10 15:13:00    Antalya            Akdeniz       Kitap
# 2  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu  Elektronik
# 3  2025-08-09 08:42:00      Konya         İç Anadolu    Kozmetik
# 4  2024-07-30 09:06:00      Konya         İç Anadolu  Elektronik
#
#              urun_adi  adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# 0        Nemlendirici     1       414.51           0.05          49.9
# 1        Girişimcilik     5       194.78           0.00          49.9
# 2           Powerbank     3       841.80           0.05          39.9
# 3        Nemlendirici     2       417.02           0.00          59.9
# 4  Bluetooth Hoparlör     1      1327.75           0.05          29.9
#
#        odeme_turu musteri_tipi  teslimat_gunu  musteri_puani iade_durumu  \
# 0     Kredi Kartı         Yeni            3.0            5.0       Hayır
# 1    Kapıda Ödeme         Yeni            3.0            5.0       Hayır
# 2  Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
# 3  Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
# 4     Banka Kartı       Mevcut            4.0            5.0       Hayır
#
#    kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 0            0.220        443.68          2024            1            13
# 1            0.250       1023.80          2024            8            10
# 2            0.280       2439.03          2024            8            19
# 3            0.220        893.94          2025            8             9
# 4            0.283       1291.26          2024            7            30
#
#   haftanın_gunu
# 0      Saturday
# 1      Saturday
# 2        Monday
# 3      Saturday
# 4       Tuesday

# %%
#kategoriye gore temel analiz
kategori_analizi = df.groupby("kategori").agg(
    {
    "toplam_tutar" : ["count","mean","sum"],
    "birim_fiyat" : "mean",
    "musteri_puani" : "mean",
    "teslimat_gunu" : "mean"

    }
    ).round(1)
kategori_analizi
# Out:
#            toplam_tutar                   birim_fiyat musteri_puani  \
#                   count    mean       sum        mean          mean
# kategori
# Elektronik          145  1515.9  219801.1      1064.7           4.2
# Ev Yaşam            186   768.0  142848.2       365.0           4.3
# Kitap               227   508.7  115483.4       224.8           4.3
# Kozmetik            203   740.8  150382.3       374.4           4.4
# Ofis                165   288.9   47665.1       138.4           4.2
# Spor                192  1026.0  196999.0       617.7           4.2
#
#            teslimat_gunu
#                     mean
# kategori
# Elektronik           3.3
# Ev Yaşam             3.5
# Kitap                3.4
# Kozmetik             3.3
# Ofis                 3.1
# Spor                 3.2

# %%
# sehre gore temel analiz
sehir_analiz = df.groupby("sehir").agg(
    {
        "toplam_tutar"  : ["sum","mean"],
        "teslimat_gunu" : "mean",
        "musteri_puani" : "mean"
    }
).round(1)

sehir_analiz
# Out:
#           toplam_tutar        teslimat_gunu musteri_puani
#                    sum   mean          mean          mean
# sehir
# Adana          50488.0  788.9           3.4           4.3
# Ankara         98429.2  781.2           3.1           4.2
# Antalya        63712.8  740.8           3.5           4.3
# Bursa          48047.0  696.3           3.5           4.2
# Eskişehir      37550.0  834.4           3.2           4.2
# Gaziantep      39181.3  753.5           3.5           4.3
# Kayseri        25592.8  656.2           3.6           4.3
# Kocaeli        21635.9  676.1           3.3           4.2
# Konya          59819.6  766.9           3.3           4.4
# Mersin         38043.9  827.0           3.5           4.2
# Samsun         38533.0  819.9           3.2           4.4
# Trabzon        30886.7  686.4           3.4           4.2
# i̇stanbul     226637.3  858.5           3.3           4.4
# i̇zmir         91526.2  756.4           3.1           4.2
# İstanbul        3095.4  773.9           4.5           4.5

# %%
# usteri tipine gore temel analiz

musteri_analiz = df.groupby("musteri_tipi").agg(
    {
        "toplam_tutar"  : ["sum","mean"],
        "teslimat_gunu" : "mean",
        "musteri_puani" : "mean"
    }
).round(1)

musteri_analiz
# Out:
#              toplam_tutar        teslimat_gunu musteri_puani
#                       sum   mean          mean          mean
# musteri_tipi
# Mevcut           452928.6  791.8           3.3           4.3
# VIP              109307.3  840.8           3.3           4.3
# Yeni             310943.2  747.5           3.2           4.3

# %%
odeme_analiz = df.groupby("odeme_turu").agg(
    {
        "toplam_tutar"  : ["sum","mean"],
        "teslimat_gunu" : "mean",
        "musteri_puani" : "mean"
    }
).round(1)

odeme_analiz
# Out:
#                toplam_tutar        teslimat_gunu musteri_puani
#                         sum   mean          mean          mean
# odeme_turu
# Banka Kartı        145815.0  838.0           3.5           4.2
# Dijital Cüzdan     136656.9  870.4           3.3           4.3
# Havale/EFT          93289.7  832.9           3.1           4.2
# Kapıda Ödeme        48389.4  604.9           3.2           4.4
# Kredi Kartı        449028.2  754.7           3.3           4.3

# %% [markdown]
# # Grup bazlı Analiz
#
# **Amaç:**
#
# 1. Veri setini farklı kırılımlara ayırarak grup bazlı analiz yapalım
# 2. groupby yapısı ile özet istatistikler üretip sonuçları yorumlamak
# Adımlar:
#
# 1. Veri setini yüklemek
# 2. Grup bazlı analiz için kullanılacak sütunları belirle
# 3. Kategoriye göre temel analiz
# 4. Şehre göre temel analiz
# 5. Müşteri tipine göre temel analiz
# 6. Ödeme türüne göre temel analiz
# 7. Birden fazla sütun ile grup bazlı analiz

# %%
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
# grup abzlı analiz icin kulanılacak sutunlar :
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id  \
# 0             0             0           0  SIP101125    MUS1391
# 1             3             3           3  SIP100263    MUS1008
# 2             4             4           4  SIP100707    MUS1291
# 3             5             5           5  SIP100687    MUS1147
# 4            10            10          10  SIP100254    MUS1447
#
#         siparis_tarihi      sehir              bolge    kategori  \
# 0  2024-01-13 17:06:00  i̇stanbul            Marmara    Kozmetik
# 1  2024-08-10 15:13:00    Antalya            Akdeniz       Kitap
# 2  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu  Elektronik
# 3  2025-08-09 08:42:00      Konya         İç Anadolu    Kozmetik
# 4  2024-07-30 09:06:00      Konya         İç Anadolu  Elektronik
#
#              urun_adi  adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# 0        Nemlendirici     1       414.51           0.05          49.9
# 1        Girişimcilik     5       194.78           0.00          49.9
# 2           Powerbank     3       841.80           0.05          39.9
# 3        Nemlendirici     2       417.02           0.00          59.9
# 4  Bluetooth Hoparlör     1      1327.75           0.05          29.9
#
#        odeme_turu musteri_tipi  teslimat_gunu  musteri_puani iade_durumu  \
# 0     Kredi Kartı         Yeni            3.0            5.0       Hayır
# 1    Kapıda Ödeme         Yeni            3.0            5.0       Hayır
# 2  Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
# 3  Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
# 4     Banka Kartı       Mevcut            4.0            5.0       Hayır
#
#    kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 0            0.220        443.68          2024            1            13
# 1            0.250       1023.80          2024            8            10
# 2            0.280       2439.03          2024            8            19
# 3            0.220        893.94          2025            8             9
# 4            0.283       1291.26          2024            7            30
#
#   haftanın_gunu
# 0      Saturday
# 1      Saturday
# 2        Monday
# 3      Saturday
# 4       Tuesday

# %%
# 3. kategoriye göre temel analiz
kategori_analizi = df.groupby("kategori").agg(
    {
        "toplam_tutar": ["count", "mean", "sum"],
        "birim_fiyat": "mean",
        "musteri_puani": "mean",
        "teslimat_gunu": "mean"
    }
).round(1)
kategori_analizi
# Out:
#            toplam_tutar                   birim_fiyat musteri_puani  \
#                   count    mean       sum        mean          mean
# kategori
# Elektronik          145  1515.9  219801.1      1064.7           4.2
# Ev Yaşam            186   768.0  142848.2       365.0           4.3
# Kitap               227   508.7  115483.4       224.8           4.3
# Kozmetik            203   740.8  150382.3       374.4           4.4
# Ofis                165   288.9   47665.1       138.4           4.2
# Spor                192  1026.0  196999.0       617.7           4.2
#
#            teslimat_gunu
#                     mean
# kategori
# Elektronik           3.3
# Ev Yaşam             3.5
# Kitap                3.4
# Kozmetik             3.3
# Ofis                 3.1
# Spor                 3.2

# %%
kategori_musteri_tipi_analizi = df.groupby(["kategori","musteri_tipi"]).agg(
    {
    "toplam_tutar" : ["mean","sum"],
    "musteri_puani" : "mean",
    "teslimat_gunu" : "mean"
    }
).round(1)

kategori_musteri_tipi_analizi
# Out:
#                         toplam_tutar           musteri_puani teslimat_gunu
#                                 mean       sum          mean          mean
# kategori   musteri_tipi
# Elektronik Mevcut             1591.2  127297.1           4.3           3.4
#            VIP                1364.6   28657.2           4.0           3.0
#            Yeni               1451.1   63846.8           4.2           3.3
# Ev Yaşam   Mevcut              792.2   76848.2           4.3           3.5
#            VIP                 837.7   18428.6           4.3           3.5
#            Yeni                710.0   47571.4           4.2           3.3
# Kitap      Mevcut              478.0   54492.0           4.3           3.5
#            VIP                 577.9   15604.2           4.1           3.6
#            Yeni                527.8   45387.2           4.2           3.2
# Kozmetik   Mevcut              720.1   82088.4           4.3           3.4
#            VIP                 725.9   20325.0           4.5           3.8
#            Yeni                786.4   47968.9           4.6           3.1
# Ofis       Mevcut              273.5   20513.5           4.3           3.1
#            VIP                 252.7    3538.3           4.1           2.6
#            Yeni                310.7   23613.4           4.2           3.3
# Spor       Mevcut              996.6   91689.4           4.3           3.2
#            VIP                1264.1   22753.9           4.4           3.0
#            Yeni               1006.8   82555.6           4.2           3.3

# %% [markdown]
# # Pivot Tablo Analizi
#
# ### Amaç
# Veri setini iki yönlü kırılımlar ile özetleyerek pivot tablo mantığını kavramak, karşılaştırmalı analizler yapmak ve ortaya çıkan sonuçları yorumlamak.
#
# ---
#
# ###Analiz Adımları
#
# **1. Veri Setinin Yüklenmesi ve Hazırlanması**
# Analize başlamadan önce veri seti ortama aktarılır. Veri setinde yer alan ve tekrar eden kayıtlar sebebiyle oluşan gereksiz isimsiz sütunlar (Unnamed) temizlenerek veri analize hazır hale getirilir.
#
# **2. Kategori ve Müşteri Tipine Göre Pivot Tablo Analizi**
# Ürün kategorileri ile müşteri profilleri (Bireysel, Kurumsal vb.) arasındaki ilişki incelenir. Hangi müşteri grubunun hangi kategorideki ürünlere daha fazla ilgi gösterdiği ve işlem hacmi oluşturduğu tespit edilir.
#
# #### **3. Şehir ve Ödeme Türüne Göre Pivot Tablo Analizi**
# Coğrafi konumlara göre müşterilerin tercih ettiği ödeme yöntemleri (Kredi Kartı, Havale, Kapıda Ödeme vb.) kırılıma uğratılır. Şehir bazında ödeme alışkanlıklarının değişip değişmediği analiz edilir.
#
# #### **4. Kategori ve Ödeme Türüne Göre Pivot Tablo Analizi**
# Satılan ürün grupları ile bu ürünler için kullanılan ödeme yöntemleri eşleştirilir. Belirli ürün kategorilerinde (örneğin yüksek fiyatlı ürün gruplarında) taksit veya farklı ödeme türlerinin ağırlığı incelenir.
#
# #### **5. Şehir ve Müşteri Tipine Göre Pivot Tablo Analizi**
# Farklı şehirlerdeki müşteri yapısı ortaya çıkarılır. Hangi illerde kurumsal müşteri yoğunluğu olduğu, hangi illerde bireysel satışların öne çıktığı belirlenerek bölgesel müşteri dağılımı özetlenir.
#
# ---
#
# ### **Sonuçların Karşılaştırılması ve Yorumlanması**
# Oluşturulan iki yönlü tablolar üzerinden en yüksek ve en düşük yoğunluğa sahip kesişim noktaları belirlenir. Çıkan sonuçlar doğrultusunda müşteri eğilimleri ve operasyonel durumlara yönelik stratejik yorumlar yapılır.

# %% [markdown]
# ## 1. Neden PIVOT TABLE Kullanıyoruz?
#
# * Veriyi Özetleme: Binlerce satırlık ham veriyi büyük resme dönüştürmek için kullanıyoruz.
# * Hızlı Karşılaştırma: Kategorik değişkenlerin (örn: bölge, yıl, segment) birbiriyle ilişkisini anında görmek için tercih ediyoruz.
# * Agregasyon: Veriyi gruplayıp aynı anda toplam, ortalama veya sayı (count) gibi metrikleri hızlıca hesaplamamızı sağlıyor.
#
# ## 2. Mantıksal Yapısı (Nasıl Kuruyoruz?)
# Pivot tabloyu oluştururken şu 4 temel parametreyi ekiyoruz:
# ```python
# index: Satırda görmek istediğimiz kategorik değişken.
# columns: Sütunda görmek istediğimiz kategorik değişken.
# values: İçeride hesaplayacağımız sayısal sütun.
# aggfunc: Hesaplama yöntemimiz ('mean', 'sum', 'count' vb.).
# ```
# ## 3. Kod Pratiğimiz
# ```python
# import pandas as pd
# # Örnek DataFrame (Hatırlatma amaçlı hızlı veri setimiz)
#
# df = pd.DataFrame({
#     'Yil':,
#     'Bolge': ['Marmara', 'Ege', 'Marmara', 'Marmara', 'Ege', 'Ege'],
#     'Satis':,
#     'Gelir': [5000, 7000, 9000, 5500, 8500, 12000]
# })
# ```
# # SENARYO 1: Temel Pivot (Yıl ve Bölge bazında Toplam Satış)
#
# ```python
# pivot_temel = df.pivot_table(
#     index='Yil',
#     columns='Bolge',
#     values='Satis',
#     aggfunc='sum'
# )
# print(pivot_temel)
# ```
# # SENARYO 2: İleri Seviye Pivot (Çoklu Metrik ve Genel Toplamlar)
# ```python
# pivot_gelismis = df.pivot_table(
#     index='Yil',
#     columns='Bolge',
#     values=['Satis', 'Gelir'],
#     aggfunc={'Satis': 'sum', 'Gelir': 'mean'}, # Satış için toplam, gelir için ortalama aldık
#     fill_value=0,                               # Boş (NaN) kalan hücrelere 0 bastık
#     margins=True                                # Sağa ve alta "All" (Genel Toplam) ekledik
# )
# print(pivot_gelismis)
# ```
# ------------------------------
# Bu notu kaydettikten sonra, bir sonraki aşama olarak bu pivot tablolardan otomatik grafik üretme (plot) adımını ekleyelim mi, yoksa doğrudan kendi gerçek veri setimizi import edip onun üzerinde mi uygulayalım?

# %%
import pandas as pd
# "Unnamed" ifadesini içeren tüm sütunları filtreleyip kaldırır

# %%
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

df.head()
# Out:
#   siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391  2024-01-13 17:06:00  i̇stanbul            Marmara
# 1  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya            Akdeniz
# 2  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 3  SIP100687    MUS1147  2025-08-09 08:42:00      Konya         İç Anadolu
# 4  SIP100254    MUS1447  2024-07-30 09:06:00      Konya         İç Anadolu
#
#      kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik        Nemlendirici     1       414.51           0.05
# 1       Kitap        Girişimcilik     5       194.78           0.00
# 2  Elektronik           Powerbank     3       841.80           0.05
# 3    Kozmetik        Nemlendirici     2       417.02           0.00
# 4  Elektronik  Bluetooth Hoparlör     1      1327.75           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 2          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 3          59.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 4          29.9     Banka Kartı       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 0       Hayır            0.220        443.68          2024            1
# 1       Hayır            0.250       1023.80          2024            8
# 2       Hayır            0.280       2439.03          2024            8
# 3       Hayır            0.220        893.94          2025            8
# 4       Hayır            0.283       1291.26          2024            7
#
#    siparis_gunu haftanın_gunu
# 0            13      Saturday
# 1            10      Saturday
# 2            19        Monday
# 3             9      Saturday
# 4            30       Tuesday

# %%
# kategori ve müsteri tipine gore pivot tablo analizi
# her kategori icin musteri tiplerine goe ortalama toplam tutar

pivot_kategori_musteri = pd.pivot_table(
    df,
    index = "kategori",
    columns= "musteri_tipi",
    values = "toplam_tutar",
    aggfunc = "mean"
).round(1)

pivot_kategori_musteri
# Out:
# musteri_tipi  Mevcut     VIP    Yeni
# kategori
# Elektronik    1591.2  1364.6  1451.1
# Ev Yaşam       792.2   837.7   710.0
# Kitap          478.0   577.9   527.8
# Kozmetik       720.1   725.9   786.4
# Ofis           273.5   252.7   310.7
# Spor           996.6  1264.1  1006.8

# %%
# sehir ve odeme turu gore pivot tablo analizi
# her sehir icin odeme turune  gore  toplam tutar

pivot_sehir_odeme_turu = pd.pivot_table(
    df,
    index = "sehir",
    columns= "odeme_turu",
    values = "toplam_tutar",
    aggfunc = "sum"
).round(1)

pivot_sehir_odeme_turu
# Out:
# odeme_turu  Banka Kartı  Dijital Cüzdan  Havale/EFT  Kapıda Ödeme  Kredi Kartı
# sehir
# Adana            9186.0          9134.0      5565.5        2466.4      24136.0
# Ankara          15472.2         13798.7     12892.8        7329.5      48936.1
# Antalya         10871.3          7115.7      6658.0        5511.6      33556.2
# Bursa            3694.8          8030.9      5853.7        6371.3      24096.3
# Eskişehir        4313.3          8010.6       707.9        3395.3      21122.9
# Gaziantep        4930.2          9558.0      3746.8        1395.0      19551.3
# Kayseri          2957.4          2947.4      6466.2        3307.6       9914.1
# Kocaeli          1922.1          5792.3      2891.3        2839.0       8191.2
# Konya           15601.8          9379.3      4558.2        2611.8      27668.4
# Mersin           9461.5          4307.8      2454.0         153.2      21667.4
# Samsun           5540.0          9928.5      3619.5         177.3      19267.8
# Trabzon          6164.2          2179.8      4533.4           NaN      18009.3
# i̇stanbul       45444.9         32388.6     24390.1        5655.6     118758.1
# i̇zmir          10255.4         14085.4      8385.8        6894.2      51905.6
# İstanbul            NaN             NaN       566.4         281.7       2247.4

# %%
# kategori ve odeme turune gore pivot tablo analizi
pivot_kategori_odeme = pd.pivot_table(
    df,
    index = "kategori",
    columns = "odeme_turu",
    values = "musteri_puani",
    aggfunc = "mean"
).round(2)

pivot_kategori_odeme
# Out:
# odeme_turu  Banka Kartı  Dijital Cüzdan  Havale/EFT  Kapıda Ödeme  Kredi Kartı
# kategori
# Elektronik         4.04            4.28        4.28          4.43         4.25
# Ev Yaşam           4.16            4.23        4.00          4.20         4.37
# Kitap              4.29            4.21        4.00          4.62         4.27
# Kozmetik           4.47            4.33        4.36          4.53         4.42
# Ofis               4.29            4.15        4.30          4.31         4.25
# Spor               4.19            4.36        4.06          4.15         4.27

# %%
# sehir ve musteri tipine gore pivot table analizi

pivot_sehir_musteri_tipi = pd.pivot_table(
    df,
    index = "sehir",
    columns = "musteri_tipi",
    values = "kargo_ucreti",
    aggfunc = "mean"
).round(1)

pivot_sehir_musteri_tipi
# Out:
# musteri_tipi  Mevcut   VIP  Yeni
# sehir
# Adana           39.9  34.9  42.1
# Ankara          41.9  37.1  39.9
# Antalya         38.6  36.6  40.2
# Bursa           38.6  41.3  40.2
# Eskişehir       36.4  39.9  39.0
# Gaziantep       38.4  46.2  41.6
# Kayseri         43.7  45.9  41.9
# Kocaeli         42.6  46.6  41.0
# Konya           38.4  35.9  39.9
# Mersin          40.7  39.9  41.0
# Samsun          39.1  37.9  36.8
# Trabzon         34.9  35.9  43.8
# i̇stanbul       39.5  39.6  36.8
# i̇zmir          41.6  38.4  38.0
# İstanbul        20.0   NaN  39.9

# %% [markdown]
# # Veri Görselleştirme
#
# ### Amaç
# * **Veri setindeki** farklı değişkenleri uygun grafik türüyle görselleştirmek
# * **Grafikler üzerinden** zaman değişimi, ilişki, karşılaştırma ve dağılım yapısını incelemek
#
# ---
#
# ### Adımlar
#
# 1. **Veri setini** yüklemek
# 2. **Line plot** ile zaman içindeki değişimi görselleştirmek
# 3. **Scatter plot** ile iki sayısal değişken arasındaki ilişkiyi görselleştirmek
# 4. **Bar plot** ile karşılaştırmalı görselleştirme yapmak
# 5. **Histogram** ile sayısal dağılım görselleştirmek
# 6. **Box plot** ile dağılım ve aykırı değer tespiti yapmak

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme()

# %%
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()
# Out:
#   siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391  2024-01-13 17:06:00  i̇stanbul            Marmara
# 1  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya            Akdeniz
# 2  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 3  SIP100687    MUS1147  2025-08-09 08:42:00      Konya         İç Anadolu
# 4  SIP100254    MUS1447  2024-07-30 09:06:00      Konya         İç Anadolu
#
#      kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik        Nemlendirici     1       414.51           0.05
# 1       Kitap        Girişimcilik     5       194.78           0.00
# 2  Elektronik           Powerbank     3       841.80           0.05
# 3    Kozmetik        Nemlendirici     2       417.02           0.00
# 4  Elektronik  Bluetooth Hoparlör     1      1327.75           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 2          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 3          59.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 4          29.9     Banka Kartı       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 0       Hayır            0.220        443.68          2024            1
# 1       Hayır            0.250       1023.80          2024            8
# 2       Hayır            0.280       2439.03          2024            8
# 3       Hayır            0.220        893.94          2025            8
# 4       Hayır            0.283       1291.26          2024            7
#
#    siparis_gunu haftanın_gunu
# 0            13      Saturday
# 1            10      Saturday
# 2            19        Monday
# 3             9      Saturday
# 4            30       Tuesday

# %%
#line plot ile zaman icindeki değişim grafigini yapalım

# siparis tarihini datetie'a değiştirelim
df["siparis_tarihi"] = pd.to_datetime(df['siparis_tarihi'])
df["siparis_ayi"] = df['siparis_tarihi'].dt.month
df.head()
# Out:
#   siparis_id musteri_id      siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391 2024-01-13 17:06:00  i̇stanbul            Marmara
# 1  SIP100263    MUS1008 2024-08-10 15:13:00    Antalya            Akdeniz
# 2  SIP100707    MUS1291 2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 3  SIP100687    MUS1147 2025-08-09 08:42:00      Konya         İç Anadolu
# 4  SIP100254    MUS1447 2024-07-30 09:06:00      Konya         İç Anadolu
#
#      kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik        Nemlendirici     1       414.51           0.05
# 1       Kitap        Girişimcilik     5       194.78           0.00
# 2  Elektronik           Powerbank     3       841.80           0.05
# 3    Kozmetik        Nemlendirici     2       417.02           0.00
# 4  Elektronik  Bluetooth Hoparlör     1      1327.75           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 2          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 3          59.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 4          29.9     Banka Kartı       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 0       Hayır            0.220        443.68          2024            1
# 1       Hayır            0.250       1023.80          2024            8
# 2       Hayır            0.280       2439.03          2024            8
# 3       Hayır            0.220        893.94          2025            8
# 4       Hayır            0.283       1291.26          2024            7
#
#    siparis_gunu haftanın_gunu
# 0            13      Saturday
# 1            10      Saturday
# 2            19        Monday
# 3             9      Saturday
# 4            30       Tuesday

# %%
aylik_toplam_tutar = df.groupby("siparis_ayi")["toplam_tutar"].sum().reset_index()

aylik_toplam_tutar
# ay bazında toplam siparis tutarlari
# Out:
#     siparis_ayi  toplam_tutar
# 0             1      69297.43
# 1             2      70064.13
# 2             3      73573.70
# 3             4      68903.73
# 4             5      93356.00
# 5             6      82688.56
# 6             7      68909.32
# 7             8      58676.79
# 8             9      81345.42
# 9            10      61096.86
# 10           11      64532.86
# 11           12      80734.43

# %%
plt.figure(figsize =(6,3))
plt.plot(aylik_toplam_tutar['siparis_ayi'],aylik_toplam_tutar['toplam_tutar'],marker="o") #line plot
plt.xlabel("Aylar")
plt.ylabel("Toplam Tutar")
plt.xticks(aylik_toplam_tutar['siparis_ayi'])
plt.tight_layout()
plt.show()

# %%
# odeme turune gore toplam harcama

odemeye_gore_harcama = df.groupby('odeme_turu')["toplam_tutar"].sum().reset_index()
odemeye_gore_harcama
# Out:
#        odeme_turu  toplam_tutar
# 0     Banka Kartı     145815.03
# 1  Dijital Cüzdan     136656.92
# 2      Havale/EFT      93289.72
# 3    Kapıda Ödeme      48389.41
# 4     Kredi Kartı     449028.15

# %%
plt.figure(figsize = (10,6))
plt.plot(odemeye_gore_harcama['odeme_turu'],odemeye_gore_harcama['toplam_tutar'], marker = "o",color="g" )
plt.xlabel("Odeme Turu")
plt.ylabel("Toplam Tutar")
plt.xticks(odemeye_gore_harcama['odeme_turu'])
plt.fill_between(odemeye_gore_harcama['odeme_turu'], odemeye_gore_harcama['toplam_tutar'], color="r", alpha=0.2)
plt.tight_layout()
plt.show()

# %%
# scatter ile iki sayısal degisken arasındaki iliskiyi gorsellestirelim
# birim fiyat ile toplam tutar arasındak korelasyona bakalım
plt.figure(figsize=(6,4))
plt.scatter(
    df['birim_fiyat'], df['toplam_tutar'],
    alpha = 0.6,
    color = "g",
    s = 5
)
plt.title("Birim fiyat ve toplam tutar ilişkisi ")
plt.xlabel("Birim Fiyat")
plt.ylabel("Toplam Fiyat")
plt.show()

# %%
# bar plot ile karsılastırmalı gorsellestirme
# kategorye gore toplam tutarı hesaplayayıp barplot ile gosrsellestirme

kategori_toplam_tutar = (
    df.groupby("kategori")["toplam_tutar"]
    .sum()
    .sort_values(ascending = False)
    .reset_index()
)

kategori_toplam_tutar
# Out:
#      kategori  toplam_tutar
# 0  Elektronik     219801.14
# 1        Spor     196999.01
# 2    Kozmetik     150382.33
# 3    Ev Yaşam     142848.20
# 4       Kitap     115483.45
# 5        Ofis      47665.10

# %%
plt.figure(figsize=(8,4))
sns.barplot(
    data = kategori_toplam_tutar,
    x= "kategori",
    y="toplam_tutar",
    color ="g",
)
plt.title("kategoriye gore toplam tutar")
plt.xlabel("kategori")
plt.ylabel("toplam tutar")
plt.xticks(rotation = 45)
plt.show()

# %%
# histogram ile sayısal dagılım gorsellesirme

plt.figure(figsize=(6,5))
plt.hist(df['toplam_tutar'],bins=150,color ="g")
plt.title("Toplam Tutar Dağılımı")
plt.xlabel("toplam_tutar")
plt.ylabel("frekans")
plt.show()

# %%
#box plot ile dagılım ve outlier tespiti

plt.figure(figsize=(10,5))
sns.boxplot(
    data=df,
    x="kategori",
    y="toplam_tutar",
    )
plt.xlabel("kategori")
plt.ylabel("toplam tutar")
plt.title("kategoriye gore toplam tutar dağılımı")
plt.show()

# %% [markdown]
# # Zaman Serisi Analizi
#
# Amaç:
# 1. Veri setindeki tarih iblgisini kullanarak zaman bazlı analiz yapmak
#
# Adımlar:
# 1. Veri setini yüklemek
# 2. Siparis tarihini datetime  tipine donustur
# 3. Tarih sütunundan zaman ozellkleirni türet
# 4. Aylara gore siprasi yogunlugunu incele
# 5. Ayın ilk yarısı ve ikinci yarisindaki harcama farkını incele
# 6. Hafta içi ve hafta sonu sipraiş davranışlarını karşılaştırma
# 7. İKi haftalık donemlerde ortalama siparis tutarı inceleme

# %%
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()
# Out:
#   siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391  2024-01-13 17:06:00  i̇stanbul            Marmara
# 1  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya            Akdeniz
# 2  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 3  SIP100687    MUS1147  2025-08-09 08:42:00      Konya         İç Anadolu
# 4  SIP100254    MUS1447  2024-07-30 09:06:00      Konya         İç Anadolu
#
#      kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik        Nemlendirici     1       414.51           0.05
# 1       Kitap        Girişimcilik     5       194.78           0.00
# 2  Elektronik           Powerbank     3       841.80           0.05
# 3    Kozmetik        Nemlendirici     2       417.02           0.00
# 4  Elektronik  Bluetooth Hoparlör     1      1327.75           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 2          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 3          59.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 4          29.9     Banka Kartı       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 0       Hayır            0.220        443.68          2024            1
# 1       Hayır            0.250       1023.80          2024            8
# 2       Hayır            0.280       2439.03          2024            8
# 3       Hayır            0.220        893.94          2025            8
# 4       Hayır            0.283       1291.26          2024            7
#
#    siparis_gunu haftanın_gunu
# 0            13      Saturday
# 1            10      Saturday
# 2            19        Monday
# 3             9      Saturday
# 4            30       Tuesday

# %%
# siparis tariihni dateime cevirelim
df['siparis_tarihi'] = pd.to_datetime(df["siparis_tarihi"])
df['siparis_tarihi'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#tarih sutunundan zaman feature olsuturalım
df["siparis_yili"] = df["siparis_tarihi"].dt.year
df["siparis_ayi"] = df["siparis_tarihi"].dt.month
df["siparis_gunu"] = df["siparis_tarihi"].dt.day
df["haftanin_gunu"] = df["siparis_tarihi"].dt.day_name()
df["hafta_numarasi"] = df["siparis_tarihi"].dt.isocalendar().week.astype(int)
df.head()
# Out:
#   siparis_id musteri_id      siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391 2024-01-13 17:06:00  i̇stanbul            Marmara
# 1  SIP100263    MUS1008 2024-08-10 15:13:00    Antalya            Akdeniz
# 2  SIP100707    MUS1291 2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 3  SIP100687    MUS1147 2025-08-09 08:42:00      Konya         İç Anadolu
# 4  SIP100254    MUS1447 2024-07-30 09:06:00      Konya         İç Anadolu
#
#      kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik        Nemlendirici     1       414.51           0.05
# 1       Kitap        Girişimcilik     5       194.78           0.00
# 2  Elektronik           Powerbank     3       841.80           0.05
# 3    Kozmetik        Nemlendirici     2       417.02           0.00
# 4  Elektronik  Bluetooth Hoparlör     1      1327.75           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 2          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 3          59.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 4          29.9     Banka Kartı       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 0       Hayır            0.220        443.68          2024            1
# 1       Hayır            0.250       1023.80          2024            8
# 2       Hayır            0.280       2439.03          2024            8
# 3       Hayır            0.220        893.94          2025            8
# 4       Hayır            0.283       1291.26          2024            7
#
#    siparis_gunu haftanın_gunu haftanin_gunu  hafta_numarasi
# 0            13      Saturday      Saturday               2
# 1            10      Saturday      Saturday              32
# 2            19        Monday        Monday              34
# 3             9      Saturday      Saturday              32
# 4            30       Tuesday       Tuesday              31

# %%
# aylara gore siparis yogunlugu

aylik_yogunluk = (
    df.groupby("siparis_ayi")
    .agg(
        siparis_sayisi = ("siparis_id","count"),
        benzersiz_musteri_sayisi = ("musteri_id","nunique")
    )
    .reset_index()
    .sort_values("siparis_ayi")
)
aylik_yogunluk
# Out:
#     siparis_ayi  siparis_sayisi  benzersiz_musteri_sayisi
# 0             1              98                        89
# 1             2              86                        75
# 2             3              97                        81
# 3             4             112                        94
# 4             5             104                        94
# 5             6              88                        77
# 6             7              80                        71
# 7             8              82                        71
# 8             9              94                        83
# 9            10              90                        80
# 10           11              88                        78
# 11           12              99                        88

# %%
plt.figure(figsize=(15,5))
plt.title("Aylara gore siparis sayısı")
plt.plot(aylik_yogunluk["siparis_ayi"],aylik_yogunluk["siparis_sayisi"], marker = "o", color = "green", label="siparis_sayisi")
plt.plot(aylik_yogunluk["siparis_ayi"],aylik_yogunluk["benzersiz_musteri_sayisi"], marker = "o", color = "red",label="benzersiz_musteri_sayisi" )
plt.xlabel("Aylara göre sipariş yoğunluğu ve benzersiz müşteri sayısı")
plt.ylabel("Siparis sayısı ve benzersiz müşteri sayısı")
plt.legend()
plt.xticks(aylik_yogunluk["siparis_ayi"])
plt.show()

# %%
# ayın ilk ve ikinci yarısı arasındaki harcama farkını inceleme
df["ay_donemi"] = df['siparis_gunu'].apply(
    lambda x : "Ayın İlk yarısı "  if x <= 15 else "Ayın ikinci yarısı"
)

df.head()
# Out:
#   siparis_id musteri_id      siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391 2024-01-13 17:06:00  i̇stanbul            Marmara
# 1  SIP100263    MUS1008 2024-08-10 15:13:00    Antalya            Akdeniz
# 2  SIP100707    MUS1291 2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 3  SIP100687    MUS1147 2025-08-09 08:42:00      Konya         İç Anadolu
# 4  SIP100254    MUS1447 2024-07-30 09:06:00      Konya         İç Anadolu
#
#      kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik        Nemlendirici     1       414.51           0.05
# 1       Kitap        Girişimcilik     5       194.78           0.00
# 2  Elektronik           Powerbank     3       841.80           0.05
# 3    Kozmetik        Nemlendirici     2       417.02           0.00
# 4  Elektronik  Bluetooth Hoparlör     1      1327.75           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 2          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 3          59.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 4          29.9     Banka Kartı       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 0       Hayır            0.220        443.68          2024            1
# 1       Hayır            0.250       1023.80          2024            8
# 2       Hayır            0.280       2439.03          2024            8
# 3       Hayır            0.220        893.94          2025            8
# 4       Hayır            0.283       1291.26          2024            7
#
#    siparis_gunu haftanın_gunu haftanin_gunu  hafta_numarasi  \
# 0            13      Saturday      Saturday               2
# 1            10      Saturday      Saturday              32
# 2            19        Monday        Monday              34
# 3             9      Saturday      Saturday              32
# 4            30       Tuesday       Tuesday              31
#
#             ay_donemi
# 0    Ayın İlk yarısı
# 1    Ayın İlk yarısı
# 2  Ayın ikinci yarısı
# 3    Ayın İlk yarısı
# 4  Ayın ikinci yarısı

# %%
ay_donemi_analizi = (
    df.groupby("ay_donemi")
    .agg(
        toplam_tutar = ("toplam_tutar", "sum")
    )
    .round(1)
    .reset_index()
)
ay_donemi_analizi
# Out:
#             ay_donemi  toplam_tutar
# 0  Ayın ikinci yarısı      424087.0
# 1    Ayın İlk yarısı       449092.3

# %%
plt.figure(figsize=(6,3))
sns.barplot(data=ay_donemi_analizi, x = "ay_donemi", y = "toplam_tutar")
plt.title("Ayın ilk yarısı ve ikinci yarısına gore toplam tutar")
plt.xlabel("Ay dönemi")
plt.ylabel("Toplam tutar")
plt.show()

# %%
df["hafta_tipi"] = df["siparis_tarihi"].dt.dayofweek.apply(
    lambda x: "hafta sonu" if x >= 5 else "hafta ici"
)
df.head()
# Out:
#   siparis_id musteri_id      siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391 2024-01-13 17:06:00  i̇stanbul            Marmara
# 1  SIP100263    MUS1008 2024-08-10 15:13:00    Antalya            Akdeniz
# 2  SIP100707    MUS1291 2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 3  SIP100687    MUS1147 2025-08-09 08:42:00      Konya         İç Anadolu
# 4  SIP100254    MUS1447 2024-07-30 09:06:00      Konya         İç Anadolu
#
#      kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik        Nemlendirici     1       414.51           0.05
# 1       Kitap        Girişimcilik     5       194.78           0.00
# 2  Elektronik           Powerbank     3       841.80           0.05
# 3    Kozmetik        Nemlendirici     2       417.02           0.00
# 4  Elektronik  Bluetooth Hoparlör     1      1327.75           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 2          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 3          59.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 4          29.9     Banka Kartı       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 0       Hayır            0.220        443.68          2024            1
# 1       Hayır            0.250       1023.80          2024            8
# 2       Hayır            0.280       2439.03          2024            8
# 3       Hayır            0.220        893.94          2025            8
# 4       Hayır            0.283       1291.26          2024            7
#
#    siparis_gunu haftanın_gunu haftanin_gunu  hafta_numarasi  \
# 0            13      Saturday      Saturday               2
# 1            10      Saturday      Saturday              32
# 2            19        Monday        Monday              34
# 3             9      Saturday      Saturday              32
# 4            30       Tuesday       Tuesday              31
#
#             ay_donemi  hafta_tipi
# 0    Ayın İlk yarısı   hafta sonu
# 1    Ayın İlk yarısı   hafta sonu
# 2  Ayın ikinci yarısı   hafta ici
# 3    Ayın İlk yarısı   hafta sonu
# 4  Ayın ikinci yarısı   hafta ici

# %%
hafta_tipi_analizi = (
    df.groupby("hafta_tipi")
    .agg(
        ortalama_siparis_tutari = ("toplam_tutar", "mean"),
    )
    .round(1)
    .reset_index()
)
hafta_tipi_analizi
# Out:
#    hafta_tipi  ortalama_siparis_tutari
# 0   hafta ici                    788.1
# 1  hafta sonu                    763.9

# %%
plt.figure()
sns.barplot(data = hafta_tipi_analizi, x = "hafta_tipi", y = "ortalama_siparis_tutari")
plt.title("Hafta içi ve hafta sonu ortalama sipariş tutarı")
plt.xlabel("Hafta tipi")
plt.ylabel("Ortalama sipariş tutarı")
plt.show()

# %%
#iki haftalık dönemelerde ortalama sipariş tutarı
df["iki_haftalik_donem"] = ((df["hafta_numarasi"] - 1)//2) + 1
df.head()
# Out:
#   siparis_id musteri_id      siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391 2024-01-13 17:06:00  i̇stanbul            Marmara
# 1  SIP100263    MUS1008 2024-08-10 15:13:00    Antalya            Akdeniz
# 2  SIP100707    MUS1291 2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 3  SIP100687    MUS1147 2025-08-09 08:42:00      Konya         İç Anadolu
# 4  SIP100254    MUS1447 2024-07-30 09:06:00      Konya         İç Anadolu
#
#      kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik        Nemlendirici     1       414.51           0.05
# 1       Kitap        Girişimcilik     5       194.78           0.00
# 2  Elektronik           Powerbank     3       841.80           0.05
# 3    Kozmetik        Nemlendirici     2       417.02           0.00
# 4  Elektronik  Bluetooth Hoparlör     1      1327.75           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 2          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 3          59.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 4          29.9     Banka Kartı       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 0       Hayır            0.220        443.68          2024            1
# 1       Hayır            0.250       1023.80          2024            8
# 2       Hayır            0.280       2439.03          2024            8
# 3       Hayır            0.220        893.94          2025            8
# 4       Hayır            0.283       1291.26          2024            7
#
#    siparis_gunu haftanın_gunu haftanin_gunu  hafta_numarasi  \
# 0            13      Saturday      Saturday               2
# 1            10      Saturday      Saturday              32
# 2            19        Monday        Monday              34
# 3             9      Saturday      Saturday              32
# 4            30       Tuesday       Tuesday              31
#
#             ay_donemi  hafta_tipi  iki_haftalik_donem
# 0    Ayın İlk yarısı   hafta sonu                   1
# 1    Ayın İlk yarısı   hafta sonu                  16
# 2  Ayın ikinci yarısı   hafta ici                  17
# 3    Ayın İlk yarısı   hafta sonu                  16
# 4  Ayın ikinci yarısı   hafta ici                  16

# %%
iki_haftalik_analiz = (
    df.groupby("iki_haftalik_donem")
    .agg(
        ortalama_siparis_tutari = ("toplam_tutar", "mean")
    )
    .round(2)
    .reset_index()
    .sort_values("iki_haftalik_donem")
)
iki_haftalik_analiz
# Out:
#     iki_haftalik_donem  ortalama_siparis_tutari
# 0                    1                   744.65
# 1                    2                   667.21
# 2                    3                   917.07
# 3                    4                   807.80
# 4                    5                   699.19
# 5                    6                   751.62
# 6                    7                   767.42
# 7                    8                   596.97
# 8                    9                   606.74
# 9                   10                   876.16
# 10                  11                   908.27
# 11                  12                   923.82
# 12                  13                   960.16
# 13                  14                   917.74
# 14                  15                   814.64
# 15                  16                   719.16
# 16                  17                   749.55
# 17                  18                   768.69
# 18                  19                   912.08
# 19                  20                   779.99
# 20                  21                   691.27
# 21                  22                   730.14
# 22                  23                   649.50
# 23                  24                   803.40
# 24                  25                   867.22
# 25                  26                   639.10

# %%
plt.figure(figsize = (10,4))
plt.plot(iki_haftalik_analiz["iki_haftalik_donem"], iki_haftalik_analiz["ortalama_siparis_tutari"], marker = "o")
plt.title("İki haftalık dönemlere göre ortalama sipariş tutarı")
plt.xlabel("iki haftalık dönem")
plt.xticks(iki_haftalik_analiz["iki_haftalik_donem"])
plt.ylabel("ortalama sipariş tutarı")
plt.show()

# %% [markdown]
# # Değişkenler Arası İlişkiler
#
# **Amaç:**
#
#  - Sayısal değişkenler arasındaki ilişkileri korelasyon analizi ile incelemek
# - Heatmap ile görselleştirme yapmak
#
# **Adımlar:**
#
# 1. Veri setini yüklemek
# 2. Sayısal sütunları belirle
# 3. Korelasyon matrisi oluştur
# 4. Korelasyon matrisini heatmap ile görselleştir

# %%
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()
# Out:
#   siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391  2024-01-13 17:06:00  i̇stanbul            Marmara
# 1  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya            Akdeniz
# 2  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 3  SIP100687    MUS1147  2025-08-09 08:42:00      Konya         İç Anadolu
# 4  SIP100254    MUS1447  2024-07-30 09:06:00      Konya         İç Anadolu
#
#      kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik        Nemlendirici     1       414.51           0.05
# 1       Kitap        Girişimcilik     5       194.78           0.00
# 2  Elektronik           Powerbank     3       841.80           0.05
# 3    Kozmetik        Nemlendirici     2       417.02           0.00
# 4  Elektronik  Bluetooth Hoparlör     1      1327.75           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 2          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 3          59.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 4          29.9     Banka Kartı       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 0       Hayır            0.220        443.68          2024            1
# 1       Hayır            0.250       1023.80          2024            8
# 2       Hayır            0.280       2439.03          2024            8
# 3       Hayır            0.220        893.94          2025            8
# 4       Hayır            0.283       1291.26          2024            7
#
#    siparis_gunu haftanın_gunu
# 0            13      Saturday
# 1            10      Saturday
# 2            19        Monday
# 3             9      Saturday
# 4            30       Tuesday

# %%
# sayısal sütunları belirle
sayisal_sutunlar = df.select_dtypes(include = ["int64", "float64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar',
#  'siparis_yili',
#  'siparis_ayi',
#  'siparis_gunu']

# %%
#korelasyon matrisi
korelasyon_matrisi = df[sayisal_sutunlar].corr()
korelasyon_matrisi
# Out:
#                      adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# adet             1.000000    -0.172037       0.014056      0.029817
# birim_fiyat     -0.172037     1.000000      -0.002959      0.020365
# indirim_orani    0.014056    -0.002959       1.000000     -0.005902
# kargo_ucreti     0.029817     0.020365      -0.005902      1.000000
# teslimat_gunu    0.007066    -0.017076       0.062526     -0.002782
# musteri_puani   -0.008313     0.001819       0.001875      0.021532
# kar_marji_orani -0.004022    -0.012597      -0.009412      0.005995
# toplam_tutar     0.431298     0.715325      -0.029227      0.031335
# siparis_yili     0.025269    -0.029667       0.030139      0.080541
# siparis_ayi      0.072451    -0.032613       0.026300     -0.019754
# siparis_gunu    -0.006776    -0.035132       0.018062      0.003063
#
#                  teslimat_gunu  musteri_puani  kar_marji_orani  toplam_tutar  \
# adet                  0.007066      -0.008313        -0.004022      0.431298
# birim_fiyat          -0.017076       0.001819        -0.012597      0.715325
# indirim_orani         0.062526       0.001875        -0.009412     -0.029227
# kargo_ucreti         -0.002782       0.021532         0.005995      0.031335
# teslimat_gunu         1.000000       0.012041         0.013934     -0.000424
# musteri_puani         0.012041       1.000000        -0.016907      0.005573
# kar_marji_orani       0.013934      -0.016907         1.000000     -0.013396
# toplam_tutar         -0.000424       0.005573        -0.013396      1.000000
# siparis_yili          0.033204      -0.041689        -0.025318     -0.011546
# siparis_ayi           0.005221      -0.047589         0.036676      0.015629
# siparis_gunu         -0.018844      -0.029110        -0.027248     -0.034309
#
#                  siparis_yili  siparis_ayi  siparis_gunu
# adet                 0.025269     0.072451     -0.006776
# birim_fiyat         -0.029667    -0.032613     -0.035132
# indirim_orani        0.030139     0.026300      0.018062
# kargo_ucreti         0.080541    -0.019754      0.003063
# teslimat_gunu        0.033204     0.005221     -0.018844
# musteri_puani       -0.041689    -0.047589     -0.029110
# kar_marji_orani     -0.025318     0.036676     -0.027248
# toplam_tutar        -0.011546     0.015629     -0.034309
# siparis_yili         1.000000     0.047905     -0.032232
# siparis_ayi          0.047905     1.000000     -0.030697
# siparis_gunu        -0.032232    -0.030697      1.000000

# %%
#korelasyon matrisini heatmap ile görselleştirme
sns.heatmap(korelasyon_matrisi, annot = True, fmt = ".1f", cmap = "coolwarm", linewidth = 0.5)
plt.title("Korelasyon Analizi")
plt.show()

# %% [markdown]
# # Veri Hikayeleştirme ve İş Yorumu
# **Amaç:**
#
# - Gerçek hayata benzeyen iş sorularını veri ile cevaplamak
# - Analiz sonuçlarını tablo, grafik ve kısa iş yorumları ile sunmak
#
# **Adımlar:**
#
# 1. Hangi kategori hem yüksek gelir üretiyor hem de müşteri memnuniyeti açısından güçlü görünüyor?
# 2. Hangi ödeme türleri daha yüksek ortalama sipariş tutarı üretiyor ve müşteri puanı açısından performans gösteriyor?
# 3. Hangi şehir-kategori kombinasyonları en güçlü fırsatı sunuyor?

# %%
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()
# Out:
#   siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391  2024-01-13 17:06:00  i̇stanbul            Marmara
# 1  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya            Akdeniz
# 2  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 3  SIP100687    MUS1147  2025-08-09 08:42:00      Konya         İç Anadolu
# 4  SIP100254    MUS1447  2024-07-30 09:06:00      Konya         İç Anadolu
#
#      kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik        Nemlendirici     1       414.51           0.05
# 1       Kitap        Girişimcilik     5       194.78           0.00
# 2  Elektronik           Powerbank     3       841.80           0.05
# 3    Kozmetik        Nemlendirici     2       417.02           0.00
# 4  Elektronik  Bluetooth Hoparlör     1      1327.75           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 2          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 3          59.9  Dijital Cüzdan       Mevcut            4.0            5.0
# 4          29.9     Banka Kartı       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 0       Hayır            0.220        443.68          2024            1
# 1       Hayır            0.250       1023.80          2024            8
# 2       Hayır            0.280       2439.03          2024            8
# 3       Hayır            0.220        893.94          2025            8
# 4       Hayır            0.283       1291.26          2024            7
#
#    siparis_gunu haftanın_gunu
# 0            13      Saturday
# 1            10      Saturday
# 2            19        Monday
# 3             9      Saturday
# 4            30       Tuesday

# %%
#hangi kategori hem yüksek gelir hem de müşteri memnuniyetini yüksek sağlıyor
kategori_raporu = (
    df.groupby("kategori")
    .agg(
        toplam_gelir = ("toplam_tutar", "sum"),
        ortalama_musteri_puani = ("musteri_puani", "mean")
    )
    .round(2)
)

# %%
kategori_raporu = kategori_raporu.sort_values(by = ["toplam_gelir"], ascending=[False])
kategori_raporu
# Out:
#             toplam_gelir  ortalama_musteri_puani
# kategori
# Elektronik     219801.14                    4.23
# Spor           196999.01                    4.25
# Kozmetik       150382.33                    4.42
# Ev Yaşam       142848.20                    4.26
# Kitap          115483.45                    4.26
# Ofis            47665.10                    4.25

# %%
#kategoriye göre toplam gelir
plt.figure(figsize = (8,4))
sns.barplot(data = kategori_raporu, x = "kategori", y = "toplam_gelir")
plt.title("Kategoriye göre toplam gelir")
plt.xlabel("Kategori")
plt.ylabel("Toplam Gelir")
plt.show()

# %%
#kategoriye göre ortalama musteri puani
plt.figure(figsize = (8,4))
sns.barplot(data = kategori_raporu, x = "kategori", y = "ortalama_musteri_puani", color ="r")
plt.title("Kategoriye göre ortalama müşteri puanı")
plt.xlabel("Kategori")
plt.ylabel("Müşteri Puanı")
plt.show()

# %%
#hangi ödeme türleri daha yüksek ortalama sipariş tutarı üretiyor ve müşteri puanı açısından nasıl performans gösteriyor?
odeme_turu_raporu = (
    df.groupby("odeme_turu")
    .agg(
        ortalama_siparis_tutari = ("toplam_tutar", "mean"),
        ortalama_musteri_puani = ("musteri_puani", "mean")
    )
    .round(2)
    .sort_values("ortalama_siparis_tutari", ascending = False)
)
odeme_turu_raporu
# Out:
#                 ortalama_siparis_tutari  ortalama_musteri_puani
# odeme_turu
# Dijital Cüzdan                   870.43                    4.27
# Banka Kartı                      838.02                    4.24
# Havale/EFT                       832.94                    4.15
# Kredi Kartı                      754.67                    4.31
# Kapıda Ödeme                     604.87                    4.38

# %%
# ödeme türüne göre ortalama sipariş tutarı
plt.figure(figsize = (8,4))
sns.barplot(data = odeme_turu_raporu, x = "odeme_turu", y = "ortalama_siparis_tutari")
plt.title("Ödeme türüne göre ortalama sipariş tutarı")
plt.xlabel("Ödeme Türü")
plt.ylabel("Ortalama Sipariş Tutarı")
plt.show()

# %%
# ödeme türüne göre ortalama müşteri puanı
plt.figure(figsize = (8,4))
sns.barplot(data = odeme_turu_raporu, x = "odeme_turu", y = "ortalama_musteri_puani")
plt.title("Ödeme türüne göre ortalama müşteri puanı")
plt.xlabel("Ödeme Türü")
plt.ylabel("Ortalama müşteri puanı")
plt.show()

# %%
#Hangi şehir-kategori kombinasyonları en güçlü fırsatı sunuyor?
sehir_kategori_raporu = (
    df.groupby(["sehir", "kategori"])
    .agg(toplam_gelir = ("toplam_tutar", "sum"))
    .round(2)
    .sort_values(["toplam_gelir"], ascending = False)
)
sehir_kategori_raporu
# Out:
#                       toplam_gelir
# sehir     kategori
# i̇stanbul Elektronik      66731.92
#           Spor            57406.29
#           Ev Yaşam        33640.51
#           Kozmetik        32543.77
#           Kitap           26821.53
# ...                            ...
# Kayseri   Ofis             1054.40
# Kocaeli   Ofis             1026.94
#           Elektronik        779.13
# İstanbul  Kitap             566.38
#           Ev Yaşam          490.08
#
# [87 rows x 1 columns]

# %%
# en güçlü 10 şehir kategori kombinasyonun görselleştir
en_guclu_10_kombinasyon = sehir_kategori_raporu.head(10).reset_index()
plt.figure(figsize = (10,4))
sns.barplot(
    data = en_guclu_10_kombinasyon,
    x = "sehir",
    y = "toplam_gelir",
    hue = "kategori"
)
plt.title("En güçlü 10 şehir-kategori kombinasyonu")
plt.xlabel("şehir")
plt.ylabel("toplam gelir")
plt.show()
